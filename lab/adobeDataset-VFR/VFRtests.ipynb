# %%
cd VFR_real_test/AnnaStd/

# %%
cd drive/MyDrive/colabData/VFR_real_test/AnnaStd

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

import pytesseract
import shutil
import os
import numpy as np
import random
from google.colab.patches import cv2_imshow
try:
 from PIL import Image
except ImportError:
 import Image
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...

# %%
import os
os.kill(os.getpid(), 9)

# %%
import cv2
import pytesseract
import numpy as np
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
import os
os.kill(os.getpid(), 9)

# %%
# tessdata_dir_config = r'--tessdata-dir "/usr/local/bin/pytesseracttessdata"'
pytesseract.pytesseract.tesseract_cmd = (r'/usr/local/bin/pytesseract')
# pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
# !ls
# Out:
# AnnaStd1008.png  AnnaStd2153.png  AnnaStd2979.png  AnnaStd4252.png
# AnnaStd1025.png  AnnaStd2269.png  AnnaStd3270.png  AnnaStd458.png
# AnnaStd1144.png  AnnaStd22.png	  AnnaStd349.png   AnnaStd470.png
# AnnaStd1278.png  AnnaStd2318.png  AnnaStd3501.png  AnnaStd503.png
# AnnaStd1396.png  AnnaStd2427.png  AnnaStd3511.png  AnnaStd580.png
# AnnaStd1435.png  AnnaStd2496.png  AnnaStd354.png   AnnaStd621.png
# AnnaStd1666.png  AnnaStd2516.png  AnnaStd3565.png  AnnaStd837.png
# AnnaStd1721.png  AnnaStd2529.png  AnnaStd3761.png  AnnaStd847.png
# AnnaStd1762.png  AnnaStd2536.png  AnnaStd3845.png  AnnaStd889.png
# AnnaStd1871.png  AnnaStd2716.png  AnnaStd3891.png  AnnaStd925.png
# AnnaStd1923.png  AnnaStd2873.png  AnnaStd3893.png  AnnaStd951.png
# AnnaStd2094.png  AnnaStd2876.png  AnnaStd4123.png
# AnnaStd2120.png  AnnaStd2885.png  AnnaStd4190.png

# %%
filelist = ['drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1008.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2153.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2979.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd4252.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1025.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2269.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3270.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd458.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1144.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd22.png'	, 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd349.png',  'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd470.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1278.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2318.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3501.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd503.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1396.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2427.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3511.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd580.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1435.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2496.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd354.png',  'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd621.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1666.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2516.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3565.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd837.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1721.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2529.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3761.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd847.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1762.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2536.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3845.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd889.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1871.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2716.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3891.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd925.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd1923.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2873.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd3893.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd951.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2094.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2876.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd4123.png',
            'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2120.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd2885.png', 'drive/MyDrive/colabData/VFR_real_test/AnnaStd/AnnaStd4190.png']

# %%
x = np.array([np.array(Image.open(fname)) for fname in filelist])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
constGray = 80
for i in range(len(x)):
  x[i][x[i] > constGray] = 255
  x[i][x[i] <= constGray] = 0
# x[x < 128] = 0

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter

# im = Image.open(filelist[0]) # the second one 
im = Image.open('drive/MyDrive/colabData/VFR_real_test/ACaslonPro-Bold/ACaslonPro-Bold3359.png') # the second one 
im = im.filter(ImageFilter.MedianFilter())
enhancer = ImageEnhance.Contrast(im)
im = enhancer.enhance(2)
im = im.convert('1')
im.save('temp2.jpg')
text = pytesseract.image_to_string(Image.open('temp2.jpg'))
#      pytesseract.image_to_string(Image.open(image_path_in_colab), lang="rus")
print(text)

# %%
for i in range(len(x)):
  cv2_imshow(x[i])
# Out:
# <PIL.Image.Image image mode=L size=173x57 at 0x7FE2A48A7250>
# <PIL.Image.Image image mode=L size=243x68 at 0x7FE2B688C9D0>
# <PIL.Image.Image image mode=L size=287x25 at 0x7FE2B688C5D0>
# <PIL.Image.Image image mode=L size=217x58 at 0x7FE2A48A7DD0>
# <PIL.Image.Image image mode=L size=494x128 at 0x7FE2B688C910>
# <PIL.Image.Image image mode=L size=741x131 at 0x7FE2B688CE10>
# <PIL.Image.Image image mode=L size=142x40 at 0x7FE2B688C5D0>
# <PIL.Image.Image image mode=L size=170x92 at 0x7FE2B688CE10>
# <PIL.Image.Image image mode=L size=450x143 at 0x7FE2B688C910>
# <PIL.Image.Image image mode=L size=292x50 at 0x7FE2B688CBD0>
# <PIL.Image.Image image mode=L size=318x92 at 0x7FE2B9186A90>
# <PIL.Image.Image image mode=L size=364x72 at 0x7FE2B688C5D0>
# <PIL.Image.Image image mode=L size=114x38 at 0x7FE2A48A7E50>
# <PIL.Image.Image image mode=L size=161x60 at 0x7FE2A48A7E50>
# <PIL.Image.Image image mode=L size=125x51 at 0x7FE2B688CC90>
# ...
