# %%
# pip install Pillow
from PIL import Image, ImageDraw, ImageFont
import numpy as np
from matplotlib import cm
import random
import string

# %%
fontPath = '/content/Roboto-Black.ttf'
fontPath = 'drive/MyDrive/colabData/fontData/fonts/ARIBLK.TTF'
fontPath = '/content/drive/MyDrive/colabData/fontData/fonts/Roboto-Regular.ttf'
fontPath = '/content/drive/MyDrive/colabData/fontData/data/serif/Alice.ttf'
fontPath = '/content/drive/MyDrive/colabData/fontData/data/contrast/nonHC/ABeeZee.ttf'
# fontPath = '/content/drive/MyDrive/colabData/fontData/data/contrast/Alegreya.ttf'
fontPath = '/content/drive/MyDrive/colabData/fontData/data/width/Wide/AZLatinWideC.otf'

# %%
dataPath = '/content/drive/MyDrive/colabData/fontData/data/slab/'
serifPath = '/content/drive/MyDrive/colabData/fontData/data/serif'
sansPath = '/content/drive/MyDrive/colabData/fontData/data/sans serif'
serifImgPath = '/content/drive/MyDrive/colabData/fontData/data/img/serif'
sansImgPath = '/content/drive/MyDrive/colabData/fontData/data/img/sans serif'
# dataPath = '/content/drive/MyDrive/colabData/fontData/allFonts'

# %%
def generateRandomSample(fontPath, picSize=(200,50)):
  im = Image.new('RGB', picSize, color=('#FFFFFF'))
  font = ImageFont.truetype(fontPath, size=30)
  draw_text = ImageDraw.Draw(im)
  draw_text.text(
      (5, 5),
      generate_random_string(20),
      font=font,
      fill='#000000')
  return im


def generate_random_string(length):
  letters = string.ascii_letters
  rand_string = ''.join(random.choice(letters) for i in range(length))
  # print("Random string of length", length, "is:", rand_string)
  return rand_string

# %%
generateRandomSample(fontPath)
# Out:
# <PIL.Image.Image image mode=RGB size=200x50 at 0x7F33AF9065D0>

# %% [markdown]
# ## Import .json

# %%
import json
import urllib.request

# %%
with open('/content/drive/MyDrive/colabData/fontData/data_30.03.2022.json') as json_file:
    data = json.load(json_file)
    # print(data)

# %%
classifications = ['Display', 'Sans Serif', 'Serif', 'Monospaced', 'Handwritten', 'Calligraphic', 'Brushed Script', 'Handrawn', 'Script']
handwritten = ['Handwritten', 'Calligraphic', 'Brushed Script', 'Handrawn', 'Script']

# %%
classifications = ['High Contrast', 'nonHC']
classifications = ['Oblique', 'True Italics', 'Cursive']
# handwritten = ['Handwritten', 'Calligraphic', 'Brushed Script', 'Handrawn', 'Script']

# %%
import os, errno

def createCatalog(directory):
    try:
      os.makedirs(directory)
    except OSError as e:
      if e.errno != errno.EEXIST:
          raise

# %%
import os

stdPath = '/content/drive/MyDrive/colabData/fontData/data/txtClassification/'
for i in classifications:
  path = stdPath + str(i)
  createCatalog(path)
# for i in handwritten[1:]:
#   path = stdPath + str(i)
#   os.rmdir(path)

# %%
stdPath = '/content/drive/MyDrive/colabData/fontData/data/slab/img/'
for i in classifications:
  path = stdPath + str(i)
  createCatalog(path)
# for i in handwritten[1:]:
#   path = stdPath + str(i)
#   os.rmdir(path)

# %%
import os

for i in classifications:
  path = '/content/drive/MyDrive/colabData/fontData/data/imgPolina/' + str(i)
  createCatalog(path)
for i in handwritten[1:]:
  path = '/content/drive/MyDrive/colabData/fontData/data/imgPolina/' + str(i)
  os.rmdir(path)

# %%
cnt = 0
for el, idx in enumerate(data['fonts'][:1000]):
  if 'regular' in idx['files'] and 'latin' in idx['subsets']:
    url = idx['files']['regular']
    name = idx['family']+'.ttf'
    urllib.request.urlretrieve(url, dataPath + '/' + name)
    cnt+=1
print('Count:      ', cnt)
# Out:
# Count:       747

# %%
uniquer = ['']
cnt = 0
cntNonHC = 0
for el, idx in enumerate(data['fonts'][:1000]):
  if 'italic' in idx['files'] and 'latin' in idx['subsets']:
    url = idx['files']['italic']
    name = idx['family']+'.ttf'

    # for i in idx['tags']:
    #   if i in classifications:
        # if i in handwritten:
    urllib.request.urlretrieve(url, dataPath + str(i) + '/' + name)
    cntNonHC+=1
      # else:
      #   urllib.request.urlretrieve(url, dataPath + str(i) + '/' + name)
      #   cnt+=1
    # if idx['category'] == 'sans-serif':
    #   # print(idx['family']+'.ttf')
    #   # print(idx['files']['regular'])
    #   # urllib.request.urlretrieve(url, sansPath + '/' + name)
    # elif idx['category'] == 'serif':
    #   # print(idx['family']+'.ttf', 'serif')
    #   # print(idx['files']['regular'])
    #   # urllib.request.urlretrieve(url, serifPath + '/' + name)
    #   cnt += 1 
    # if idx['category'] in uniquer:
    #   continue
    # uniquer.append(str(idx['category']))
  # print(uniquer)
print('Handwritten:', cntNonHC)
print('Count:      ', cnt)
# Out:
# Handwritten: 89
# Count:       0

# %%
widthData = [('BioRhyme Expanded.ttf', 'Wide'),
 ('StingerWideTrial-Thin.ttf', 'Narrow'),
 ('StingerWideTrial-Heavy.ttf', 'Wide'),
 ('RFDewiExpanded-BlackItalic.ttf', 'Wide'),
 ('RFDewiExpanded-Bold.ttf', 'Wide'),
 ('Micra.otf', 'Wide'),
 ('BRRRTrial-Skrrt.otf', 'Wide'),
 ('StingerWideTrial-LightItalic.ttf', 'Narrow'),
 ('StingerWideTrial-ThinItalic.ttf', 'Narrow'),
 ('Pravda.otf', 'Narrow'),
 ('StingerWideTrial-Light.ttf', 'Narrow'),
 ('RFDewiExpanded-UltraboldItalic.ttf', 'Wide'),
 ('Metal-6-Trial.ttf', 'Wide'),
 ('Michroma.ttf', 'Wide'),
 ('Metal-7-Trial.otf', 'Wide'),
 ('Transgender Grotesk-Regular-Trial.otf', 'Wide'),
 ('StingerWideTrial-Italic.ttf', 'Narrow'),
 ('StingerWideTrial-HeavyItalic.ttf', 'Narrow'),
 ('RFDewiExtended-Bold.ttf', 'Narrow'),
 ('AZLatinWideC.otf', 'Wide'),
 ('Micra-Bold.otf', 'Wide'),
 ('Copperplate.ttc', 'Narrow'),
 ('Metal-6-Trial.otf', 'Wide'),
 ('Laguna-Plain.otf', 'Narrow'),
 ('StingerWideTrial-Bold.ttf', 'Narrow'),
 ('StingerWideTrial-BoldItalic.ttf', 'Narrow'),
 ('UpadokC.otf', 'Wide'),
 ('RFDewiExpanded-Ultrabold.ttf', 'Wide'),
 ('RFDewiExpanded-Black.ttf', 'Wide'),
 ('RFDewiExtended-BoldItalic.ttf', 'Narrow'),
 ('StingerWideTrial-Regular.ttf', 'Narrow'),
 ('DEJAVUSANSMONO.TTF', 'Condensed'),
 ('ARIALN.TTF', 'Condensed'),
 ('CONSOLAI.TTF', 'Narrow'),
 ('CORBELI.TTF', 'Narrow'),
 ('ARIALNI.TTF', 'Condensed'),
 ('CENSCBK.TTF', 'Narrow'),
 ('LFAXD.TTF', 'Narrow'),
 ('LFAXI.TTF', 'Narrow'),
 ('Six Caps.ttf', 'Condensed'),
 ('BenchNine.ttf', 'Condensed'),
 ('LFAX.TTF', 'Narrow'),
 ('EBRIMA.TTF', 'Narrow'),
 ('ARIALNBI.TTF', 'Narrow'),
 ('BAHNSCHRIFT (3).TTF', 'Narrow'),
 ('CONSTANB.TTF', 'Narrow'),
 ('BOOKOSI.TTF', 'Narrow'),
 ('GEORGIAB.TTF', 'Narrow'),
 ('CONSTANI.TTF', 'Narrow'),
 ('CONSTAN.TTF', 'Narrow'),
 ('BOOKOS.TTF', 'Narrow'),
 ('EBRIMABD.TTF', 'Narrow'),
 ('BAHNSCHRIFT.TTF', 'Condensed'),
 ('SCHLBKBI.TTF', 'Narrow'),
 ('COMICI.TTF', 'Narrow'),
 ('GOTHICI.TTF', 'Narrow'),
 ('DEJAVUSERIF.TTF', 'Narrow'),
 ('LSANSI.TTF', 'Narrow'),
 ('CONSOLA.TTF', 'Narrow'),
 ('GEORGIAI.TTF', 'Narrow'),
 ('LTYPE.TTF', 'Narrow'),
 ('BOOKOSBI.TTF', 'Narrow'),
 ('ARIBLK.TTF', 'Narrow'),
 ('GOTHIC.TTF', 'Narrow'),
 ('CORBELB.TTF', 'Narrow'),
 ('GOTHICBI.TTF', 'Narrow'),
 ('ANTQUAB.TTF', 'Narrow'),
 ('GOTHICB.TTF', 'Narrow'),
 ('GEORGIA.TTF', 'Narrow'),
 ('BAHNSCHRIFT (6).TTF', 'Narrow'),
 ('BAHNSCHRIFT (2).TTF', 'Narrow'),
 ('ANTQUAI.TTF', 'Narrow'),
 ('LSANS.TTF', 'Narrow'),
 ('BASKVILL.TTF', 'Narrow'),
 ('CORBEL.TTF', 'Narrow'),
 ('COMICZ.TTF', 'Narrow'),
 ('BAHNSCHRIFT (13).TTF', 'Narrow'),
 ('ANTQUABI.TTF', 'Narrow'),
 ('DEJAVUSANS.TTF', 'Narrow'),
 ('LFAXDI.TTF', 'Narrow'),
 ('BAHNSCHRIFT (8).TTF', 'Narrow'),
 ('BAHNSCHRIFT (1).TTF', 'Narrow'),
 ('LTYPEBO.TTF', 'Narrow'),
 ('LTYPEO.TTF', 'Narrow'),
 ('GEORGIAZ.TTF', 'Narrow'),
 ('BAHNSCHRIFT (10).TTF', 'Narrow'),
 ('LSANSD.TTF', 'Narrow'),
 ('Antonio.ttf', 'Condensed'),
 ('BAHNSCHRIFT (7).TTF', 'Narrow'),
 ('Fjalla One.ttf', 'Condensed'),
 ('ARIALNB.TTF', 'Condensed'),
 ('BRLNSDB.TTF', 'Narrow'),
 ('BOOKOSB.TTF', 'Narrow'),
 ('L_10646.TTF', 'Narrow'),
 ('BAHNSCHRIFT (4).TTF', 'Narrow'),
 ('BKANT.TTF', 'Narrow'),
 ('Economica.ttf', 'Condensed'),
 ('ARIAL.TTF', 'Narrow'),
 ('BAHNSCHRIFT (11).TTF', 'Narrow'),
 ('Aguafina Script.ttf', 'Condensed'),
 ('BAHNSCHRIFT (5).TTF', 'Narrow'),
 ('ARLRDBD.TTF', 'Narrow'),
 ('LTYPEB.TTF', 'Narrow'),
 ('BAHNSCHRIFT (14).TTF', 'Narrow'),
 ('BAHNSCHRIFT (9).TTF', 'Narrow'),
 ('CORBELL.TTF', 'Narrow'),
 ('Tulpen One.ttf', 'Condensed'),
 ('Voltaire.ttf', 'Condensed'),
 ('Allan.ttf', 'Condensed'),
 ('ARIALI.TTF', 'Narrow'),
 ('Amatic SC.ttf', 'Condensed'),
 ('BRLNSB.TTF', 'Narrow'),
 ('COMIC.TTF', 'Narrow'),
 ('ARIALBD.TTF', 'Narrow'),
 ('Yanone Kaffeesatz.ttf', 'Condensed'),
 ('CONSOLAB.TTF', 'Narrow'),
 ('CORBELLI.TTF', 'Narrow'),
 ('CONSOLAZ.TTF', 'Narrow'),
 ('LSANSDI.TTF', 'Narrow'),
 ('CORBELZ.TTF', 'Narrow'),
 ('ARIALBI.TTF', 'Narrow'),
 ('CONSTANZ.TTF', 'Narrow'),
 ('Pragati Narrow.ttf', 'Condensed'),
 ('BAHNSCHRIFT (12).TTF', 'Narrow'),
 ('SCHLBKI.TTF', 'Narrow'),
 ('COMICBD.TTF', 'Narrow'),
 ('SCHLBKB.TTF', 'Narrow'),
 ('BRLNSR.TTF', 'Narrow'),
 ('Carrois Gothic SC.ttf', 'Narrow'),
 ('Francois One.ttf', 'Condensed'),
 ('Open Sans.ttf', 'Condensed'),
 ('Carrois Gothic.ttf', 'Condensed'),
 ('Marvel.ttf', 'Condensed'),
 ('Slabo 13px.ttf', 'Narrow'),
 ('Road Rage.ttf', 'Condensed'),
 ('Big Shoulders Text.ttf', 'Condensed'),
 ('Teko.ttf', 'Condensed'),
 ('Encode Sans SC.ttf', 'Narrow'),
 ('Smokum.ttf', 'Condensed'),
 ('Mohave.ttf', 'Condensed'),
 ('Song Myung.ttf', 'Narrow'),
 ('Encode Sans Semi Condensed.ttf', 'Narrow'),
 ('Slabo 27px.ttf', 'Narrow'),
 ('Big Shoulders Stencil Display.ttf', 'Condensed'),
 ('Big Shoulders Inline Text.ttf', 'Condensed'),
 ('Ranga.ttf', 'Condensed'),
 ('Encode Sans Condensed.ttf', 'Narrow'),
 ('Big Shoulders Inline Display.ttf', 'Condensed'),
 ('Kelly Slab.ttf', 'Narrow'),
 ('Girassol.ttf', 'Narrow'),
 ('Antonio.ttf', 'Condensed'),
 ('Encode Sans Expanded.ttf', 'Wide'),
 ('Fjalla One.ttf', 'Condensed'),
 ('Dosis.ttf', 'Narrow'),
 ('Big Shoulders Display.ttf', 'Condensed'),
 ('Economica.ttf', 'Condensed'),
 ('Alatsi.ttf', 'Narrow'),
 ('Encode Sans.ttf', 'Narrow'),
 ('Allan.ttf', 'Condensed'),
 ('Amatic SC.ttf', 'Condensed'),
 ('Yanone Kaffeesatz.ttf', 'Condensed'),
 ('Encode Sans Semi Expanded.ttf', 'Wide'),
 ('Lekton.ttf', 'Narrow'),
 ('WindSong.ttf', 'Wide'),
 ('Oswald.ttf', 'Condensed'),
 ('Big Shoulders Stencil Text.ttf', 'Condensed')]

# %%
import shutil
import os
from PIL import Image, ImageDraw, ImageFont


def generateRandomSample(fontPath, picSize=(200,50)):
  im = Image.new('RGB', picSize, color=('#FFFFFF'))
  font = ImageFont.truetype(fontPath, size=30)
  draw_text = ImageDraw.Draw(im)
  draw_text.text(
      (5, 5),
      generate_random_string(20),
      font=font,
      fill='#000000')
  return im


def generate_random_string(length):
  letters = string.ascii_letters
  rand_string = ''.join(random.choice(letters) for i in range(length))
  # print("Random string of length", length, "is:", rand_string)
  return rand_string

pathToAll = '/content/drive/MyDrive/colabData/fontData/allFonts/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/validation/'
cnt = 0
cnt1 = 0
for idx, fname in enumerate(os.listdir(pathToAll)[:1000]):
  if 'Noto' not in fname:
    cnt += 1
    fpath = os.path.join(pathToAll, fname)
    # print(fpath)
    # print('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.png')
    # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'

    # print(fname[-12:])
    if fname[-12:]=='#regular.ttf':
      # print(fname[-13:])
      generateRandomSample(fpath).save(pathToSave+fname[:-12]+'.jpg')
    elif fname[-11:]=='#italic.ttf':
      # print(fname[-13:])
      generateRandomSample(fpath).save(pathToSave+fname[:-11]+'.jpg')
    else:
      generateRandomSample(fpath).save(pathToSave+fname[:-8]+'.jpg')
print(cnt)
# Out:
# 646

# %%
import shutil
import os

pathToAll = '/content/drive/MyDrive/colabData/fontData/allFonts/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/allPreparedFonts/'
cnt = 0
cnt1 = 0
for idx, elem in enumerate(os.listdir(pathToAll)):
  newIndex = idx % 11
  # print(newIndex, elem)
  # try:
      # sysString = 'copy ' + pathToAll + '/' + cat + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
      # print(sysString)
      # os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
  shutil.copyfile(pathToAll + elem, pathToSave + str(newIndex) + '/' + elem)

  cnt1 += 1
  # except FileNotFoundError:
  #     print('error')





  # cnt += 1
  # if i[0] in os.listdir(pathToAll + 'Narrow'):
  #   cat = 'Narrow'
  # elif i[0] in os.listdir(pathToAll + 'Condensed'):
  #   cat = 'Condensed'
  # elif i[0] in os.listdir(pathToAll + 'Wide'):
  #   cat = 'Wide'
  # else: print("###############################################################")
  # # print(cat)

  # if i[0] not in os.listdir(pathToSave + 'Narrow') \
  #     and i[0] not in os.listdir(pathToSave + 'Condensed') \
  #     and i[0] not in os.listdir(pathToSave + 'Wide'):
  #   # print(i)
  #   try:
  #     # sysString = 'copy ' + pathToAll + '/' + cat + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
  #     # print(sysString)
  #     # os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
  #     shutil.copyfile(pathToAll + cat + '/' + i[0], pathToSave + i[1] + '/' + i[0])

  #     cnt1 += 1
  #   except FileNotFoundError:
  #     print(pathToAll + cat + '/' + i[0], pathToSave + i[1] + '/' + i[0])
print('Попыток:', cnt)
print('Успешно:', cnt1)
# Out:
# Попыток: 0
# Успешно: 2697

# %%
pathToAll = '/content/drive/MyDrive/colabData/fontData/allFonts/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/data/txtClassification/'
cnt = 0
for i in data[:1000]:
  cnt += 1
  if i[0] not in os.listdir(pathToSave + 'Display') \
      and i[0] not in os.listdir(pathToSave + 'Serif') \
      and i[0] not in os.listdir(pathToSave + 'Sans Serif') \
      and i[0] not in os.listdir(pathToSave + 'Monospaced') \
      and i[0] not in os.listdir(pathToSave + 'Handwritten'):
    print(i)
    try:
      sysString = 'copy ' + pathToAll + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
      # print(sysString)
      os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
    except FileNotFoundError:
      pass
print(cnt)

# %%
import shutil

pathToAll = '/content/drive/MyDrive/colabData/fontData/data/width/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/data/txtWidth/'
cnt = 0
cnt1 = 0
for i in widthData[:1000]:
  cnt += 1
  if i[0] in os.listdir(pathToAll + 'Narrow'):
    cat = 'Narrow'
  elif i[0] in os.listdir(pathToAll + 'Condensed'):
    cat = 'Condensed'
  elif i[0] in os.listdir(pathToAll + 'Wide'):
    cat = 'Wide'
  else: print("###############################################################")
  # print(cat)

  if i[0] not in os.listdir(pathToSave + 'Narrow') \
      and i[0] not in os.listdir(pathToSave + 'Condensed') \
      and i[0] not in os.listdir(pathToSave + 'Wide'):
    # print(i)
    try:
      # sysString = 'copy ' + pathToAll + '/' + cat + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
      # print(sysString)
      # os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
      shutil.copyfile(pathToAll + cat + '/' + i[0], pathToSave + i[1] + '/' + i[0])

      cnt1 += 1
    except FileNotFoundError:
      print(pathToAll + cat + '/' + i[0], pathToSave + i[1] + '/' + i[0])
print('Попыток:', cnt)
print('Успешно:', cnt1)
# Out:
# Попыток: 166
# Успешно: 0

# %%
weightData = [
 ('BenchNine#700.ttf', '6bold'),
 ('Bellota Text#700.ttf', '5semibold'),
 ('Bellota#700.ttf', '5semibold'),
 ('Averia Serif Libre#700.ttf', '6bold'),
 ('Averia Sans Libre#700.ttf', '6bold'),
 ('Averia Libre#700.ttf', '6bold'),
 ('Atkinson Hyperlegible#700.ttf', '7heavy'),
 ('Asap Condensed#700.ttf', '7heavy'),
 ('Asap#700.ttf', '6bold'),
 ('Arvo#700.ttf', '7heavy'),
 ('Arsenal#700.ttf', '6bold'),
 ('Arimo#700.ttf', '6bold'),
 ('Archivo Narrow#700.ttf', '6bold'),
 ('Antonio#700.ttf', '7heavy'),
 ('Anonymous Pro#700.ttf', '5semibold'),
 ('Andika New Basic#700.ttf', '6bold'),
 ('Alef#700.ttf', '6bold'),
 ('Amita#700.ttf', '5semibold'),
 ('Amiko#700.ttf', '6bold'),
 ('Advent Pro#700.ttf', '6bold'),
 ('Amatic SC#700.ttf', '4medium'),
 ('Amaranth#700.ttf', '7heavy'),
 ('Almendra#700.ttf', '7heavy'),
 ('Allan#700.ttf', '8black'),
 ('Aleo#700.ttf', '6bold'),
 ('Asap Condensed#600.ttf', '6bold'),
 ('Asap#600.ttf', '6bold'),
 ('Arimo#600.ttf', '6bold'),
 ('Archivo Narrow#600.ttf', '6bold'),
 ('Antonio#600.ttf', '6bold'),
 ('Advent Pro#600.ttf', '5semibold'),
 ('Amiko#600.ttf', '6bold'),
 ('Asap Condensed#500.ttf', '6bold'),
 ('Asap#500.ttf', '6bold'),
 ('Arimo#500.ttf', '5semibold'),
 ('Archivo Narrow#500.ttf', '5semibold'),
 ('Antonio#500.ttf', '6bold'),
 ('Advent Pro#500.ttf', '4medium'),
 ('Zen Loop#regular.ttf', '0ultralight'),
 ('Zen Kurenaido#regular.ttf', '3regular'),
 ('Zen Dots#regular.ttf', '6bold'),
 ('Zen Antique Soft#regular.ttf', '6bold'),
 ('Zen Antique#regular.ttf', '6bold'),
 ('Yuji Syuku#regular.ttf', '5semibold'),
 ('Yeseva One#regular.ttf', '7heavy'),
 ('Yellowtail#regular.ttf', '6bold'),
 ('Wire One#regular.ttf', '0ultralight'),
 ('Wellfleet#regular.ttf', '6bold'),
 ('Walter Turncoat#regular.ttf', '6bold'),
 ('Wallpoet#regular.ttf', '6bold'),
 ('Voltaire#regular.ttf', '6bold'),
 ('Viga#regular.ttf', '6bold'),
 ('Vidaloka#regular.ttf', '6bold'),
 ('Vibur#regular.ttf', '6bold'),
 ('Vibes#regular.ttf', '1thin'),
 ('Vast Shadow#regular.ttf', '6bold'),
 ('Varela Round#regular.ttf', '5semibold'),
 ('Varela#regular.ttf', '5semibold'),
 ('Vampiro One#regular.ttf', '7heavy'),
 ('VT323#regular.ttf', '6bold'),
 ('UnifrakturMaguntia#regular.ttf', '6bold'),
 ('Unica One#regular.ttf', '4medium'),
 ('Uncial Antiqua#regular.ttf', '6bold'),
 ('Ultra#regular.ttf', '8black'),
 ('Ubuntu Condensed#regular.ttf', '5semibold'),
 ('Tulpen One#regular.ttf', '2light'),
 ('Trykker#regular.ttf', '5semibold'),
 ('Trocchi#regular.ttf', '5semibold'),
 ('Trade Winds#regular.ttf', '7heavy'),
 ('Titan One#regular.ttf', '8black'),
 ('The Girl Next Door#regular.ttf', '3regular'),
 ('Text Me One#regular.ttf', '2light'),
 ('Telex#regular.ttf', '4medium'),
 ('Tauri#regular.ttf', '6bold'),
 ('Syne Tactile#regular.ttf', '5semibold'),
 ('Supermercado One#regular.ttf', '6bold'),
 ('Stylish#regular.ttf', '6bold'),
 ('Style Script#regular.ttf', '5semibold'),
 ('Stoke#regular.ttf', '6bold'),
 ('Stint Ultra Expanded#regular.ttf', '2light'),
 ('Stint Ultra Condensed#regular.ttf', '4medium'),
 ('Stick#regular.ttf', '5semibold'),
 ('Squada One#regular.ttf', '6bold'),
 ('Spirax#regular.ttf', '6bold'),
 ('Spinnaker#regular.ttf', '5semibold'),
 ('Spicy Rice#regular.ttf', '8black'),
 ('Special Elite#regular.ttf', '5semibold'),
 ('Sorts Mill Goudy#regular.ttf', '5semibold'),
 ('Sonsie One#regular.ttf', '8black'),
 ('Song Myung#regular.ttf', '6bold'),
 ('Sofia#regular.ttf', '5semibold'),
 ('Sofadi One#regular.ttf', '5semibold'),
 ('Slabo 27px#regular.ttf', '4medium'),
 ('Slabo 13px#regular.ttf', '4medium'),
 ('Six Caps#regular.ttf', '5semibold'),
 ('Sirin Stencil#regular.ttf', '5semibold'),
 ('Sigmar One#regular.ttf', '8black'),
 ('Shrikhand#regular.ttf', '8black'),
 ('Short Stack#regular.ttf', '5semibold'),
 ('Shojumaru#regular.ttf', '7heavy'),
 ('Share Tech Mono#regular.ttf', '4medium'),
 ('Share Tech#regular.ttf', '4medium'),
 ('Shanti#regular.ttf', '4medium'),
 ('Sevillana#regular.ttf', '4medium'),
 ('Sedgwick Ave Display#regular.ttf', '6bold'),
 ('Sedgwick Ave#regular.ttf', '5semibold'),
 ('Schoolbell#regular.ttf', '5semibold'),
 ('Sawarabi Mincho#regular.ttf', '4medium'),
 ('Sawarabi Gothic#regular.ttf', '4medium'),
 ('Satisfy#regular.ttf', '4medium'),
 ('Sarina#regular.ttf', '8black'),
 ('Sancreek#regular.ttf', '7heavy'),
 ('Zen Old Mincho#900.ttf', '4medium'),
 ('Zen Maru Gothic#900.ttf', '5semibold'),
 ('Zen Kaku Gothic New#900.ttf', '4medium'),
 ('Zen Kaku Gothic Antique#900.ttf', '4medium'),
 ('Truculenta#900.ttf', '6bold'),
 ('Tourney#900.ttf', '6bold'),
 ('Texturina#900.ttf', '6bold'),
 ('Source Serif Pro#900.ttf', '7heavy'),
 ('Simonetta#900.ttf', '6bold'),
 ('Ruda#900.ttf', '5semibold'),
 ('Rokkitt#900.ttf', '8black'),
 ('Roboto Slab#900.ttf', '6bold'),
 ('Roboto#900.ttf', '6bold'),
 ('Red Hat Display#900.ttf', '5semibold'),
 ('Playfair Display SC#900.ttf', '6bold'),
 ('Playfair Display#900.ttf', '7heavy'),
 ('Petrona#900.ttf', '7heavy'),
 ('Overpass#900.ttf', '7heavy'),
 ('Overlock#900.ttf', '6bold'),
 ('Orbitron#900.ttf', '6bold'),
 ('Nunito#900.ttf', '6bold'),
 ('Merriweather#900.ttf', '7heavy'),
 ('Martel Sans#900.ttf', '6bold'),
 ('M PLUS Rounded 1c#900.ttf', '7heavy'),
 ('Londrina Solid#900.ttf', '8black'),
 ('Lato#900.ttf', '6bold'),
 ('Inconsolata#900.ttf', '6bold'),
 ('Imbue#900.ttf', '7heavy'),
 ('Heebo#900.ttf', '7heavy'),
 ('Grenze Gotisch#900.ttf', '7heavy'),
 ('Grenze#900.ttf', '7heavy'),
 ('Gothic A1#900.ttf', '6bold'),
 ('Fraunces#900.ttf', '7heavy'),
 ('Frank Ruhl Libre#900.ttf', '6bold'),
 ('Elsie Swash Caps#900.ttf', '6bold'),
 ('Elsie#900.ttf', '7heavy'),
 ('Darker Grotesque#900.ttf', '6bold'),
 ('Crimson Pro#900.ttf', '6bold'),
 ('Cinzel Decorative#900.ttf', '7heavy'),
 ('Cinzel#900.ttf', '6bold'),
 ('Catamaran#900.ttf', '6bold'),
 ('Bitter#900.ttf', '7heavy'),
 ('Biryani#900.ttf', '5semibold'),
 ('Be Vietnam Pro#900.ttf', '7heavy'),
 ('Arima Madurai#900.ttf', '4medium'),
 ('Archivo#900.ttf', '6bold'),
 ('Alegreya Sans SC#900.ttf', '6bold'),
 ('Truculenta#800.ttf', '5semibold'),
 ('Tourney#800.ttf', '6bold'),
 ('Tillana#800.ttf', '7heavy'),
 ('Texturina#800.ttf', '6bold'),
 ('Syne#800.ttf', '7heavy'),
 ('Stick No Bills#800.ttf', '6bold'),
 ('Spectral SC#800.ttf', '6bold'),
 ('Spectral#800.ttf', '6bold'),
 ('Sen#800.ttf', '6bold'),
 ('Ruda#800.ttf', '5semibold'),
 ('Rokkitt#800.ttf', '7heavy'),
 ('Roboto Slab#800.ttf', '6bold'),
 ('Red Hat Display#800.ttf', '4medium'),
 ('Podkova#800.ttf', '6bold'),
 ('Playfair Display#800.ttf', '6bold'),
 ('Petrona#800.ttf', '6bold'),
 ('Overpass#800.ttf', '6bold'),
 ('Orbitron#800.ttf', '6bold'),
 ('Open Sans#800.ttf', '7heavy'),
 ('Nunito#800.ttf', '6bold'),
 ('Newsreader#800.ttf', '7heavy'),
 ('Neuton#800.ttf', '7heavy'),
 ('Nanum Myeongjo#800.ttf', '4medium'),
 ('Nanum Gothic#800.ttf', '4medium'),
 ('Mukta Vaani#800.ttf', '5semibold'),
 ('Mukta Malar#800.ttf', '5semibold'),
 ('Mukta Mahee#800.ttf', '5semibold'),
 ('Mukta#800.ttf', '5semibold'),
 ('Martel Sans#800.ttf', '5semibold'),
 ('Manuale#800.ttf', '6bold'),
 ('Manrope#800.ttf', '5semibold'),
 ('M PLUS Rounded 1c#800.ttf', '6bold'),
 ('Life Savers#800.ttf', '4medium'),
 ('JetBrains Mono#800.ttf', '5semibold'),
 ('Inconsolata#800.ttf', '6bold'),
 ('Imbue#800.ttf', '7heavy'),
 ('Heebo#800.ttf', '6bold'),
 ('Grenze Gotisch#800.ttf', '6bold'),
 ('Grenze#800.ttf', '6bold'),
 ('Gothic A1#800.ttf', '5semibold'),
 ('Glory#800.ttf', '6bold'),
 ('Fraunces#800.ttf', '7heavy'),
 ('Faustina#800.ttf', '7heavy'),
 ('Dosis#800.ttf', '7heavy'),
 ('Darker Grotesque#800.ttf', '5semibold'),
 ('Crimson Pro#800.ttf', '6bold'),
 ('Coda Caption#800.ttf', '7heavy'),
 ('Cinzel#800.ttf', '6bold'),
 ('Chathura#800.ttf', '3regular'),
 ('Changa#800.ttf', '7heavy'),
 ('Catamaran#800.ttf', '6bold'),
 ('Bitter#800.ttf', '6bold'),
 ('Biryani#800.ttf', '5semibold'),
 ('BioRhyme Expanded#800.ttf', '5semibold'),
 ('BioRhyme#800.ttf', '6bold'),
 ('Big Shoulders Text#800.ttf', '5semibold'),
 ('Big Shoulders Stencil Text#800.ttf', '5semibold'),
 ('Big Shoulders Stencil Display#800.ttf', '6bold'),
 ('Big Shoulders Inline Text#800.ttf', '3regular'),
 ('Big Shoulders Inline Display#800.ttf', '3regular'),
 ('Big Shoulders Display#800.ttf', '6bold'),
 ('Be Vietnam Pro#800.ttf', '7heavy'),
 ('Baumans#800.ttf', '6bold'),
 ('Baloo Thambi 2#800.ttf', '7heavy'),
 ('Baloo Tammudu 2#800.ttf', '7heavy'),
 ('Baloo Tamma 2#800.ttf', '7heavy'),
 ('Baloo Paaji 2#800.ttf', '6bold'),
 ('Baloo Da 2#800.ttf', '6bold'),
 ('Baloo Chettan 2#800.ttf', '6bold'),
 ('Baloo Bhaina 2#800.ttf', '6bold'),
 ('Baloo Bhai 2#800.ttf', '7heavy'),
 ('Baloo 2#800.ttf', '7heavy'),
 ('Assistant#800.ttf', '7heavy'),
 ('Arima Madurai#800.ttf', '5semibold'),
 ('Archivo#800.ttf', '6bold'),
 ('Andada Pro#800.ttf', '6bold'),
 ('Abhaya Libre#800.ttf', '6bold'),
 ('Alegreya Sans SC#800.ttf', '6bold'),
 ('Zilla Slab#700.ttf', '5semibold'),
 ('Zen Old Mincho#700.ttf', '5semibold'),
 ('Zen Maru Gothic#700.ttf', '5semibold'),
 ('Zen Kaku Gothic New#700.ttf', '4medium'),
 ('Zen Kaku Gothic Antique#700.ttf', '4medium'),
 ('Yanone Kaffeesatz#700.ttf', '6bold'),
 ('Volkhov#700.ttf', '5semibold'),
 ('Unna#700.ttf', '6bold'),
 ('UnifrakturCook#700.ttf', '6bold'),
 ('Ubuntu Mono#700.ttf', '5semibold'),
 ('Ubuntu#700.ttf', '6bold'),
 ('Truculenta#700.ttf', '5semibold'),
 ('Trochut#700.ttf', '6bold'),
 ('Tourney#700.ttf', '6bold'),
 ('Tinos#700.ttf', '6bold'),
 ('Tillana#700.ttf', '6bold'),
 ('Texturina#700.ttf', '5semibold'),
 ('Tangerine#700.ttf', '2light'),
 ('Syne#700.ttf', '5semibold'),
 ('Stardos Stencil#700.ttf', '6bold'),
 ('Spectral SC#700.ttf', '6bold'),
 ('Spectral#700.ttf', '6bold'),
 ('Source Serif Pro#700.ttf', '6bold'),
 ('Sintony#700.ttf', '4medium'),
 ('Signika Negative#700.ttf', '5semibold'),
 ('Signika#700.ttf', '6bold'),
 ('Share#700.ttf', '5semibold'),
 ('Sen#700.ttf', '5semibold'),
 ('Scheherazade New#700.ttf', '6bold'),
 ('Scada#700.ttf', '6bold'),
 ('Ruda#700.ttf', '4medium'),
 ('Rosario#700.ttf', '5semibold'),
 ('Rokkitt#700.ttf', '5semibold'),
 ('Roboto Slab#700.ttf', '6bold'),
 ('Roboto Mono#700.ttf', '5semibold'),
 ('Roboto Condensed#700.ttf', '6bold'),
 ('Roboto#700.ttf', '6bold'),
 ('Red Rose#700.ttf', '5semibold'),
 ('Red Hat Mono#700.ttf', '6bold'),
 ('Red Hat Display#700.ttf', '4medium'),
 ('Ranga#700.ttf', '6bold'),
 ('Rambla#700.ttf', '5semibold'),
 ('Rajdhani#700.ttf', '5semibold'),
 ('Quicksand#700.ttf', '4medium'),
 ('Quattrocento Sans#700.ttf', '4medium'),
 ('Quattrocento#700.ttf', '4medium'),
 ('Quantico#700.ttf', '6bold'),
 ('Puritan#700.ttf', '4medium'),
 ('Pragati Narrow#700.ttf', '4medium'),
 ('Podkova#700.ttf', '4medium'),
 ('Playfair Display SC#700.ttf', '6bold'),
 ('Playfair Display#700.ttf', '6bold'),
 ('Play#700.ttf', '5semibold'),
 ('Philosopher#700.ttf', '5semibold'),
 ('Petrona#700.ttf', '5semibold'),
 ('Palanquin#700.ttf', '4medium'),
 ('PT Serif#700.ttf', '6bold'),
 ('PT Sans Narrow#700.ttf', '5semibold'),
 ('PT Sans Caption#700.ttf', '5semibold'),
 ('PT Sans#700.ttf', '5semibold'),
 ('Oxygen#700.ttf', '4medium'),
 ('Overpass Mono#700.ttf', '4medium'),
 ('Overpass#700.ttf', '4medium'),
 ('Overlock#700.ttf', '3regular'),
 ('Orbitron#700.ttf', '5semibold'),
 ('Open Sans#700.ttf', '5semibold'),
 ('Old Standard TT#700.ttf', '5semibold'),
 ('Nunito#700.ttf', '4medium'),
 ('Noticia Text#700.ttf', '5semibold'),
 ('Newsreader#700.ttf', '6bold'),
 ('News Cycle#700.ttf', '4medium'),
 ('Neuton#700.ttf', '5semibold'),
 ('Nanum Myeongjo#700.ttf', '3regular'),
 ('Nanum Gothic Coding#700.ttf', '4medium'),
 ('Nanum Gothic#700.ttf', '3regular'),
 ('Mukta Vaani#700.ttf', '4medium'),
 ('Mukta Malar#700.ttf', '4medium'),
 ('Mukta Mahee#700.ttf', '4medium'),
 ('Mukta#700.ttf', '4medium'),
 ('Mohave#700.ttf', '5semibold'),
 ('Merriweather#700.ttf', '5semibold'),
 ('Merienda#700.ttf', '5semibold'),
 ('Marvel#700.ttf', '2light'),
 ('Martel Sans#700.ttf', '4medium'),
 ('Manuale#700.ttf', '5semibold'),
 ('Manrope#700.ttf', '4medium'),
 ('Mali#700.ttf', '5semibold'),
 ('Magra#700.ttf', '6bold'),
 ('M PLUS Rounded 1c#700.ttf', '4medium'),
 ('M PLUS Code Latin#700.ttf', '6bold'),
 ('M PLUS 1 Code#700.ttf', '6bold'),
 ('Lora#700.ttf', '6bold'),
 ('Lobster Two#700.ttf', '6bold'),
 ('Life Savers#700.ttf', '3regular'),
 ('Libre Caslon Text#700.ttf', '6bold'),
 ('Libre Baskerville#700.ttf', '6bold'),
 ('Lekton#700.ttf', '4medium'),
 ('Lato#700.ttf', '4medium'),
 ('Kreon#700.ttf', '5semibold'),
 ('Karma#700.ttf', '5semibold'),
 ('Kalam#700.ttf', '5semibold'),
 ('Jura#700.ttf', '2light'),
 ('Judson#700.ttf', '5semibold'),
 ('Josefin Slab#700.ttf', '3regular'),
 ('Josefin Sans#700.ttf', '5semibold'),
 ('JetBrains Mono#700.ttf', '5semibold'),
 ('Istok Web#700.ttf', '5semibold'),
 ('Inria Serif#700.ttf', '5semibold'),
 ('Inria Sans#700.ttf', '4medium'),
 ('Inconsolata#700.ttf', '4medium'),
 ('Imbue#700.ttf', '6bold'),
 ('IBM Plex Serif#700.ttf', '6bold'),
 ('IBM Plex Sans Thai Looped#700.ttf', '6bold'),
 ('IBM Plex Sans Thai#700.ttf', '6bold'),
 ('IBM Plex Sans KR#700.ttf', '6bold'),
 ('IBM Plex Sans Hebrew#700.ttf', '6bold'),
 ('IBM Plex Sans Devanagari#700.ttf', '6bold'),
 ('IBM Plex Sans Condensed#700.ttf', '6bold'),
 ('IBM Plex Sans Arabic#700.ttf', '6bold'),
 ('IBM Plex Sans#700.ttf', '6bold'),
 ('IBM Plex Mono#700.ttf', '6bold'),
 ('Hind Vadodara#700.ttf', '6bold'),
 ('Hind Siliguri#700.ttf', '6bold'),
 ('Hind Madurai#700.ttf', '6bold'),
 ('Hind Guntur#700.ttf', '6bold'),
 ('Hind#700.ttf', '6bold'),
 ('Heebo#700.ttf', '6bold'),
 ('Gudea#700.ttf', '5semibold'),
 ('Grenze Gotisch#700.ttf', '6bold'),
 ('Grenze#700.ttf', '6bold'),
 ('Gowun Batang#700.ttf', '4medium'),
 ('Gothic A1#700.ttf', '4medium'),
 ('Glory#700.ttf', '5semibold'),
 ('Glegoo#700.ttf', '3regular'),
 ('Gentium Book Basic#700.ttf', '6bold'),
 ('Gentium Basic#700.ttf', '6bold'),
 ('Gelasio#700.ttf', '6bold'),
 ('Gaegu#700.ttf', '4medium'),
 ('Fraunces#700.ttf', '6bold'),
 ('Frank Ruhl Libre#700.ttf', '6bold'),
 ('Fira Code#700.ttf', '6bold'),
 ('Faustina#700.ttf', '6bold'),
 ('Farro#700.ttf', '6bold'),
 ('Expletus Sans#700.ttf', '6bold'),
 ('Enriqueta#700.ttf', '6bold'),
 ('El Messiri#700.ttf', '5semibold'),
 ('Economica#700.ttf', '4medium'),
 ('Dosis#700.ttf', '5semibold'),
 ('Domine#700.ttf', '5semibold'),
 ('Delius Unicase#700.ttf', '5semibold'),
 ('Darker Grotesque#700.ttf', '4medium'),
 ('Dancing Script#700.ttf', '4medium'),
 ('Crimson Pro#700.ttf', '5semibold'),
 ('Cousine#700.ttf', '5semibold'),
 ('Courier Prime#700.ttf', '5semibold'),
 ('Cormorant Upright#700.ttf', '4medium'),
 ('Cormorant Unicase#700.ttf', '4medium'),
 ('Cormorant SC#700.ttf', '5semibold'),
 ('Cormorant Infant#700.ttf', '5semibold'),
 ('Cormorant Garamond#700.ttf', '4medium'),
 ('Cormorant#700.ttf', '4medium'),
 ('Comic Neue#700.ttf', '4medium'),
 ('Comfortaa#700.ttf', '4medium'),
 ('Cinzel Decorative#700.ttf', '6bold'),
 ('Cinzel#700.ttf', '6bold'),
 ('Cherry Swash#700.ttf', '7heavy'),
 ('Chathura#700.ttf', '3regular'),
 ('Charmonman#700.ttf', '4medium'),
 ('Charm#700.ttf', '5semibold'),
 ('Changa#700.ttf', '6bold'),
 ('Caveat#700.ttf', '4medium'),
 ('Caudex#700.ttf', '5semibold'),
 ('Catamaran#700.ttf', '5semibold'),
 ('Cardo#700.ttf', '5semibold'),
 ('Cambay#700.ttf', '4medium'),
 ('Caladea#700.ttf', '6bold'),
 ('Cabin Condensed#700.ttf', '5semibold'),
 ('Cabin#700.ttf', '4medium'),
 ('Bona Nova#700.ttf', '6bold'),
 ('Bitter#700.ttf', '6bold'),
 ('Biryani#700.ttf', '5semibold'),
 ('BioRhyme Expanded#700.ttf', '5semibold'),
 ('BioRhyme#700.ttf', '6bold'),
 ('Big Shoulders Text#700.ttf', '6bold'),
 ('Big Shoulders Stencil Text#700.ttf', '6bold'),
 ('Big Shoulders Stencil Display#700.ttf', '6bold'),
 ('BenchNine#700.ttf', '4medium'),
 ('Bellota Text#700.ttf', '4medium'),
 ('Bellota#700.ttf', '3regular'),
 ('Averia Serif Libre#700.ttf', '5semibold'),
 ('Averia Sans Libre#700.ttf', '5semibold'),
 ('Averia Libre#700.ttf', '6bold'),
 ('Atkinson Hyperlegible#700.ttf', '6bold'),
 ('Asap Condensed#700.ttf', '7heavy'),
 ('Asap#700.ttf', '6bold'),
 ('Arvo#700.ttf', '6bold'),
 ('Arsenal#700.ttf', '6bold'),
 ('Arimo#700.ttf', '5semibold'),
 ('Archivo Narrow#700.ttf', '5semibold'),
 ('Antonio#700.ttf', '6bold'),
 ('Anonymous Pro#700.ttf', '4medium'),
 ('Andika New Basic#700.ttf', '5semibold'),
 ('Alef#700.ttf', '5semibold'),
 ('Amita#700.ttf', '5semibold'),
 ('Amiko#700.ttf', '5semibold'),
 ('Advent Pro#700.ttf', '5semibold'),
 ('Amatic SC#700.ttf', '2light'),
 ('Amaranth#700.ttf', '7heavy'),
 ('Almendra#700.ttf', '7heavy'),
 ('Allan#700.ttf', '6bold'),
 ('Aleo#700.ttf', '6bold'),
 ('Asap Condensed#600.ttf', '5semibold'),
 ('Asap#600.ttf', '5semibold'),
 ('Arimo#600.ttf', '5semibold'),
 ('Archivo Narrow#600.ttf', '5semibold'),
 ('Antonio#600.ttf', '5semibold'),
 ('Advent Pro#600.ttf', '4medium'),
 ('Amiko#600.ttf', '4medium'),
 ('WindSong#500.ttf', '8black'),
 ('Asap Condensed#500.ttf', '4medium'),
 ('Asap#500.ttf', '4medium'),
 ('Arimo#500.ttf', '4medium'),
 ('Archivo Narrow#500.ttf', '4medium'),
 ('Antonio#500.ttf', '5semibold'),
 ('Advent Pro#500.ttf', '3regular'),
 ('Zen Loop#regular.ttf', '0ultralight'),
 ('Zen Kurenaido#regular.ttf', '1thin'),
 ('Zen Dots#regular.ttf', '7heavy'),
 ('Zen Antique Soft#regular.ttf', '5semibold'),
 ('Zen Antique#regular.ttf', '5semibold'),
 ('Yuji Syuku#regular.ttf', '3regular'),
 ('Yeseva One#regular.ttf', '7heavy'),
 ('Yellowtail#regular.ttf', '5semibold'),
 ('Wire One#regular.ttf', '0ultralight'),
 ('Wellfleet#regular.ttf', '5semibold'),
 ('Walter Turncoat#regular.ttf', '5semibold'),
 ('Wallpoet#regular.ttf', '6bold'),
 ('Voltaire#regular.ttf', '4medium'),
 ('Viga#regular.ttf', '5semibold'),
 ('Vidaloka#regular.ttf', '5semibold'),
 ('Vibes#regular.ttf', '1thin'),
 ('Vast Shadow#regular.ttf', '6bold'),
 ('Varela Round#regular.ttf', '4medium'),
 ('Varela#regular.ttf', '4medium'),
 ('Vampiro One#regular.ttf', '7heavy'),
 ('VT323#regular.ttf', '5semibold'),
 ('UnifrakturMaguntia#regular.ttf', '6bold'),
 ('Unica One#regular.ttf', '3regular'),
 ('Uncial Antiqua#regular.ttf', '6bold'),
 ('Ultra#regular.ttf', '8black'),
 ('Ubuntu Condensed#regular.ttf', '3regular'),
 ('Tulpen One#regular.ttf', '0ultralight'),
 ('Trykker#regular.ttf', '3regular'),
 ('Trocchi#regular.ttf', '4medium'),
 ('Trade Winds#regular.ttf', '6bold'),
 ('Titan One#regular.ttf', '8black'),
 ('The Girl Next Door#regular.ttf', '1thin'),
 ('Text Me One#regular.ttf', '0ultralight'),
 ('Telex#regular.ttf', '3regular'),
 ('Tauri#regular.ttf', '4medium'),
 ('Syne Tactile#regular.ttf', '4medium'),
 ('Supermercado One#regular.ttf', '4medium'),
 ('Stylish#regular.ttf', '4medium'),
 ('Style Script#regular.ttf', '4medium'),
 ('Stoke#regular.ttf', '5semibold'),
 ('Stint Ultra Expanded#regular.ttf', '2light'),
 ('Stint Ultra Condensed#regular.ttf', '2light'),
 ('Stick#regular.ttf', '3regular'),
 ('Squada One#regular.ttf', '6bold'),
 ('Spirax#regular.ttf', '5semibold'),
 ('Spinnaker#regular.ttf', '4medium'),
 ('Spicy Rice#regular.ttf', '7heavy'),
 ('Special Elite#regular.ttf', '4medium'),
 ('Sorts Mill Goudy#regular.ttf', '3regular'),
 ('Sonsie One#regular.ttf', '8black'),
 ('Song Myung#regular.ttf', '4medium'),
 ('Sofia#regular.ttf', '4medium'),
 ('Sofadi One#regular.ttf', '4medium'),
 ('Slabo 27px#regular.ttf', '3regular'),
 ('Slabo 13px#regular.ttf', '3regular'),
 ('Six Caps#regular.ttf', '4medium'),
 ('Sirin Stencil#regular.ttf', '5semibold'),
 ('Sigmar One#regular.ttf', '8black'),
 ('Shrikhand#regular.ttf', '8black'),
 ('Short Stack#regular.ttf', '4medium'),
 ('Shojumaru#regular.ttf', '7heavy'),
 ('Share Tech Mono#regular.ttf', '3regular'),
 ('Share Tech#regular.ttf', '3regular'),
 ('Shanti#regular.ttf', '3regular'),
 ('Sevillana#regular.ttf', '3regular'),
 ('Sedgwick Ave Display#regular.ttf', '5semibold'),
 ('Sedgwick Ave#regular.ttf', '5semibold'),
 ('Schoolbell#regular.ttf', '4medium'),
 ('Sawarabi Mincho#regular.ttf', '4medium'),
 ('Sawarabi Gothic#regular.ttf', '3regular'),
 ('Satisfy#regular.ttf', '4medium'),
 ('Sarina#regular.ttf', '8black'),
 ('Sancreek#regular.ttf', '7heavy'),
 ('Sanchez#regular.ttf', '3regular'),
 ('Salsa#regular.ttf', '5semibold'),
 ('Sail#regular.ttf', '5semibold'),
 ('Rye#regular.ttf', '6bold'),
 ('Rubik Mono One#regular.ttf', '7heavy'),
 ('Rubik Beastly#regular.ttf', '8black'),
 ('Rozha One#regular.ttf', '6bold'),
 ('Rouge Script#regular.ttf', '1thin'),
 ('Rosarivo#regular.ttf', '3regular'),
 ('Romanesco#regular.ttf', '5semibold'),
 ('RocknRoll One#regular.ttf', '5semibold'),
 ('Rochester#regular.ttf', '3regular'),
 ('Road Rage#regular.ttf', '5semibold'),
 ('Risque#regular.ttf', '5semibold'),
 ('Reenie Beanie#regular.ttf', '2light'),
 ('Redressed#regular.ttf', '4medium'),
 ('Ravi Prakash#regular.ttf', '5semibold'),
 ('Rationale#regular.ttf', '3regular'),
 ('Rancho#regular.ttf', '4medium'),
 ('Ranchers#regular.ttf', '7heavy'),
 ('Ramaraja#regular.ttf', '6bold'),
 ('Ramabhadra#regular.ttf', '5semibold'),
 ('Raleway Dots#regular.ttf', '0ultralight'),
 ('Radley#regular.ttf', '4medium'),
 ('Qwigley#regular.ttf', '2light'),
 ('Quintessential#regular.ttf', '3regular'),
 ('Questrial#regular.ttf', '3regular'),
 ('Quando#regular.ttf', '4medium'),
 ('Purple Purse#regular.ttf', '6bold'),
 ('Prociono#regular.ttf', '4medium'),
 ('Press Start 2P#regular.ttf', '7heavy'),
 ('Prata#regular.ttf', '4medium'),
 ('Port Lligat Slab#regular.ttf', '4medium'),
 ('Port Lligat Sans#regular.ttf', '3regular'),
 ('Pompiere#regular.ttf', '2light'),
 ('Poly#regular.ttf', '4medium'),
 ('Poiret One#regular.ttf', '0ultralight'),
 ('Playball#regular.ttf', '4medium'),
 ('Plaster#regular.ttf', '8black'),
 ('Piedra#regular.ttf', '7heavy'),
 ('Permanent Marker#regular.ttf', '7heavy'),
 ('Peralta#regular.ttf', '7heavy'),
 ('Patua One#regular.ttf', '6bold'),
 ('Passions Conflict#regular.ttf', '1thin'),
 ('Passero One#regular.ttf', '5semibold'),
 ('Parisienne#regular.ttf', '2light'),
 ('Paprika#regular.ttf', '4medium'),
 ('Pacifico#regular.ttf', '6bold'),
 ('PT Serif Caption#regular.ttf', '4medium'),
 ('PT Mono#regular.ttf', '3regular'),
 ('Oxygen Mono#regular.ttf', '3regular'),
 ('Ovo#regular.ttf', '3regular'),
 ('Overlock SC#regular.ttf', '3regular'),
 ('Over the Rainbow#regular.ttf', '3regular'),
 ('Original Surfer#regular.ttf', '5semibold'),
 ('Oranienbaum#regular.ttf', '3regular'),
 ('Odibee Sans#regular.ttf', '5semibold'),
 ('Numans#regular.ttf', '3regular'),
 ('Nova Square#regular.ttf', '4medium'),
 ('Nova Slim#regular.ttf', '4medium'),
 ('Nova Script#regular.ttf', '4medium'),
 ('Nova Round#regular.ttf', '4medium'),
 ('Nova Oval#regular.ttf', '4medium'),
 ('Nova Mono#regular.ttf', '3regular'),
 ('Nova Flat#regular.ttf', '3regular'),
 ('Nova Cut#regular.ttf', '4medium'),
 ('Nothing You Could Do#regular.ttf', '2light'),
 ('Notable#regular.ttf', '8black'),
 ('Nosifer#regular.ttf', '7heavy'),
 ('Nixie One#regular.ttf', '0ultralight'),
 ('Niconne#regular.ttf', '5semibold'),
 ('New Tegomin#regular.ttf', '4medium'),
 ('New Rocker#regular.ttf', '6bold'),
 ('Nanum Pen Script#regular.ttf', '3regular'),
 ('Nanum Brush Script#regular.ttf', '3regular'),
 ('Mr De Haviland#regular.ttf', '2light'),
 ('Mr Dafoe#regular.ttf', '4medium'),
 ('Mouse Memoirs#regular.ttf', '5semibold'),
 ('Montez#regular.ttf', '4medium'),
 ('Molengo#regular.ttf', '3regular'),
 ('Modern Antiqua#regular.ttf', '4medium'),
 ('Modak#regular.ttf', '8black'),
 ('Miniver#regular.ttf', '4medium'),
 ('Michroma#regular.ttf', '3regular'),
 ('Metrophobic#regular.ttf', '3regular'),
 ('Metamorphous#regular.ttf', '4medium'),
 ('Metal Mania#regular.ttf', '5semibold'),
 ('Metal#regular.ttf', '4medium'),
 ('Merienda One#regular.ttf', '6bold'),
 ('MedievalSharp#regular.ttf', '5semibold'),
 ('Mate SC#regular.ttf', '4medium'),
 ('Mate#regular.ttf', '3regular'),
 ('Marck Script#regular.ttf', '4medium'),
 ('Marcellus SC#regular.ttf', '5semibold'),
 ('Marcellus#regular.ttf', '5semibold'),
 ('Mansalva#regular.ttf', '6bold'),
 ('Mandali#regular.ttf', '3regular'),
 ('Mako#regular.ttf', '3regular'),
 ('Maiden Orange#regular.ttf', '5semibold'),
 ('Macondo Swash Caps#regular.ttf', '5semibold'),
 ('Macondo#regular.ttf', '5semibold'),
 ('Luckiest Guy#regular.ttf', '8black'),
 ('Lovers Quarrel#regular.ttf', '2light'),
 ('Loved by the King#regular.ttf', '2light'),
 ('Love Ya Like A Sister#regular.ttf', '6bold'),
 ('Lobster#regular.ttf', '6bold'),
 ('Linden Hill#regular.ttf', '4medium'),
 ('Limelight#regular.ttf', '7heavy'),
 ('Libre Caslon Display#regular.ttf', '3regular'),
 ('Lemon#regular.ttf', '6bold'),
 ('Ledger#regular.ttf', '4medium'),
 ('Leckerli One#regular.ttf', '6bold'),
 ('League Script#regular.ttf', '0ultralight'),
 ('Lateef#regular.ttf', '3regular'),
 ('Langar#regular.ttf', '6bold'),
 ('Lalezar#regular.ttf', '7heavy'),
 ('Kurale#regular.ttf', '4medium'),
 ('Krona One#regular.ttf', '5semibold'),
 ('Kristi#regular.ttf', '2light'),
 ('Kotta One#regular.ttf', '4medium'),
 ('Kirang Haerang#regular.ttf', '5semibold'),
 ('Kings#regular.ttf', '4medium'),
 ('Kelly Slab#regular.ttf', '4medium'),
 ('Kavoon#regular.ttf', '7heavy'),
 ('Kavivanar#regular.ttf', '4medium'),
 ('Kaushan Script#regular.ttf', '4medium'),
 ('Just Me Again Down Here#regular.ttf', '3regular'),
 ('Just Another Hand#regular.ttf', '4medium'),
 ('Junge#regular.ttf', '3regular'),
 ('Julius Sans One#regular.ttf', '1thin'),
 ('Jomhuria#regular.ttf', '6bold'),
 ('Jolly Lodger#regular.ttf', '6bold'),
 ('Jockey One#regular.ttf', '6bold'),
 ('Jacques Francois#regular.ttf', '4medium'),
 ('Italianno#regular.ttf', '3regular'),
 ('Italiana#regular.ttf', '3regular'),
 ('Indie Flower#regular.ttf', '4medium'),
 ('Inder#regular.ttf', '4medium'),
 ('IM Fell Great Primer SC#regular.ttf', '5semibold'),
 ('IM Fell Great Primer#regular.ttf', '5semibold'),
 ('IM Fell French Canon SC#regular.ttf', '5semibold'),
 ('IM Fell French Canon#regular.ttf', '4medium'),
 ('IM Fell English SC#regular.ttf', '4medium'),
 ('IM Fell English#regular.ttf', '3regular'),
 ('IM Fell Double Pica SC#regular.ttf', '4medium'),
 ('IM Fell Double Pica#regular.ttf', '3regular'),
 ('IM Fell DW Pica SC#regular.ttf', '4medium'),
 ('IM Fell DW Pica#regular.ttf', '4medium'),
 ('Homenaje#regular.ttf', '3regular'),
 ('Homemade Apple#regular.ttf', '4medium'),
 ('Herr Von Muellerhoff#regular.ttf', '2light'),
 ('Henny Penny#regular.ttf', '5semibold'),
 ('Headland One#regular.ttf', '4medium'),
 ('Happy Monkey#regular.ttf', '3regular'),
 ('Handlee#regular.ttf', '3regular'),
 ('Hanalei Fill#regular.ttf', '7heavy'),
 ('Habibi#regular.ttf', '3regular'),
 ('Griffy#regular.ttf', '4medium'),
 ('Grey Qo#regular.ttf', '2light'),
 ('Great Vibes#regular.ttf', '3regular'),
 ('Gravitas One#regular.ttf', '8black'),
 ('Grand Hotel#regular.ttf', '4medium'),
 ('Graduate#regular.ttf', '4medium'),
 ('Gowun Dodum#regular.ttf', '3regular'),
 ('Goudy Bookletter 1911#regular.ttf', '3regular'),
 ('Gotu#regular.ttf', '3regular'),
 ('Gochi Hand#regular.ttf', '5semibold'),
 ('Goblin One#regular.ttf', '8black'),
 ('Gloria Hallelujah#regular.ttf', '3regular'),
 ('Girassol#regular.ttf', '5semibold'),
 ('Germania One#regular.ttf', '6bold'),
 ('Geo#regular.ttf', '3regular'),
 ('Gafata#regular.ttf', '3regular'),
 ('Fresca#regular.ttf', '4medium'),
 ('Freehand#regular.ttf', '4medium'),
 ('Fredoka One#regular.ttf', '6bold'),
 ('Francois One#regular.ttf', '6bold'),
 ('Forum#regular.ttf', '3regular'),
 ('Fontdiner Swanky#regular.ttf', '7heavy'),
 ('Flavors#regular.ttf', '5semibold'),
 ('Fjord One#regular.ttf', '3regular'),
 ('Fjalla One#regular.ttf', '4medium'),
 ('Finger Paint#regular.ttf', '4medium'),
 ('Felipa#regular.ttf', '3regular'),
 ('Fauna One#regular.ttf', '3regular'),
 ('Fasthand#regular.ttf', '3regular'),
 ('Fascinate#regular.ttf', '8black'),
 ('Farsan#regular.ttf', '2light'),
 ('Fanwood Text#regular.ttf', '3regular'),
 ('Explora#regular.ttf', '1thin'),
 ('Euphoria Script#regular.ttf', '2light'),
 ('Estonia#regular.ttf', '2light'),
 ('Erica One#regular.ttf', '8black'),
 ('Englebert#regular.ttf', '4medium'),
 ('Engagement#regular.ttf', '4medium'),
 ('Electrolize#regular.ttf', '4medium'),
 ('East Sea Dokdo#regular.ttf', '5semibold'),
 ('Dynalight#regular.ttf', '4medium'),
 ('Duru Sans#regular.ttf', '3regular'),
 ('Donegal One#regular.ttf', '5semibold'),
 ('Didact Gothic#regular.ttf', '3regular'),
 ('Delius Swash Caps#regular.ttf', '3regular'),
 ('Delius#regular.ttf', '3regular'),
 ('Dela Gothic One#regular.ttf', '7black'),
 ('Days One#regular.ttf', '5semibold'),
 ('Croissant One#regular.ttf', '6bold'),
 ('Crete Round#regular.ttf', '6bold'),
 ('Creepster#regular.ttf', '7heavy'),
 ('Courgette#regular.ttf', '4medium'),
 ('Copse#regular.ttf', '3regular'),
 ('Cookie#regular.ttf', '4medium'),
 ('Contrail One#regular.ttf', '5semibold'),
 ('Condiment#regular.ttf', '5semibold'),
 ('Concert One#regular.ttf', '5semibold'),
 ('Coming Soon#regular.ttf', '2light'),
 ('Comforter Brush#regular.ttf', '2light'),
 ('Comforter#regular.ttf', '2light'),
 ('Combo#regular.ttf', '2light'),
 ('Coiny#regular.ttf', '8black'),
 ('Codystar#regular.ttf', '0ultralight'),
 ('Chicle#regular.ttf', '6bold'),
 ('Cherry Cream Soda#regular.ttf', '6bold'),
 ('Cherish#regular.ttf', '2light'),
 ('Chenla#regular.ttf', '3regular'),
 ('Chelsea Market#regular.ttf', '5semibold'),
 ('Chela One#regular.ttf', '7heavy'),
 ('Chau Philomene One#regular.ttf', '5semibold'),
 ('Chango#regular.ttf', '8black'),
 ('Changa One#regular.ttf', '8black'),
 ('Ceviche One#regular.ttf', '8black'),
 ('Caveat Brush#regular.ttf', '6bold'),
 ('Carrois Gothic SC#regular.ttf', '3regular'),
 ('Carrois Gothic#regular.ttf', '3regular'),
 ('Candal#regular.ttf', '7heavy')
 ]

# %%
import shutil

pathToAll = '/content/drive/MyDrive/colabData/fontData/data/weight/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/data/txtWeight/'
cnt = 0
cnt1 = 0
for i in weightData[:2000]:
  cnt += 1
  bCat = True
  if i[0][:-8]+'.ttf' in os.listdir(pathToAll + '0ultralight'):
    cat = '0ultralight'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '1thin'):
    cat = '1thin'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '2light'):
    cat = '2light'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '3regular'):
    cat = '3regular'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '4medium'):
    cat = '4medium'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '5semibold'):
    cat = '5semibold'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '6bold'):
    cat = '6bold'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '7heavy'):
    cat = '7heavy'
    bCat = False
  elif i[0][:-8]+'.ttf' in os.listdir(pathToAll + '8black'):
    cat = '8black'
    bCat = False
  
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '0ultralight'):
    cat = '0ultralight'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '1thin'):
    cat = '1thin'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '2light'):
    cat = '2light'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '3regular'):
    cat = '3regular'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '4medium'):
    cat = '4medium'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '5semibold'):
    cat = '5semibold'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '6bold'):
    cat = '6bold'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '7heavy'):
    cat = '7heavy'
    bCat = False
  elif i[0][:-12]+'.ttf' in os.listdir(pathToAll + '8black'):
    cat = '8black'
    bCat = False

  else: print("###############################################################")
    # print(i[0][-12:]+'.ttf')
  if bCat: print(cat)

  if i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '0ultralight') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '1thin') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '2light') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '3regular') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '4medium') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '5semibold') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '6bold') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '7heavy') \
      and i[0][:-8]+'.ttf' not in os.listdir(pathToSave + '8black') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '0ultralight') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '1thin') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '2light') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '3regular') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '4medium') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '5semibold') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '6bold') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '7heavy') \
      and i[0][:-12]+'.ttf' not in os.listdir(pathToSave + '8black'):
    # print(i)  
    try:
        # sysString = 'copy ' + pathToAll + '/' + cat + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
        # print(sysString)
        # os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
        if i[0][-12:] == '#regular.ttf':
          shutil.copyfile(pathToAll + cat + '/' + i[0][:-12] + '.ttf', pathToSave + i[1] + '/' + i[0])
        else:
          shutil.copyfile(pathToAll + cat + '/' + i[0][:-8] + '.ttf', pathToSave + i[1] + '/' + i[0])
        cnt1 += 1
    except FileNotFoundError:
      print(pathToAll + cat + '/' + i[0], pathToSave + i[1] + '/' + i[0])
print('Попыток:', cnt)
print('Успешно:', cnt1)
# Out:
# /content/drive/MyDrive/colabData/fontData/data/weight/3regular/Dela Gothic One#regular.ttf /content/drive/MyDrive/colabData/fontData/data/txtWeight/7black/Dela Gothic One#regular.ttf
# Попыток: 769
# Успешно: 768

# %%
data = [('Almendra SC.ttf', 'Display'),
 ('Calligraffitti.ttf', 'Handwritten'),
 ('Sail.ttf', 'Handwritten'),
 ('Port Lligat Slab.ttf', 'Serif'),
 ('Felipa.ttf', 'Handwritten'),
 ('Londrina Solid.ttf', 'Sans Serif'),
 ('Vibes.ttf', 'Handwritten'),
 ('Dancing Script.ttf', 'Handwritten'),
 ('Lobster.ttf', 'Handwritten'),
 ('Great Vibes.ttf', 'Handwritten'),
 ('Englebert.ttf', 'Handwritten'),
 ('Petrona.ttf', 'Handwritten'),
 ('Amatic SC.ttf', 'Handwritten'),
 ('Pacifico.ttf', 'Handwritten'),
 ('Kings.ttf', 'Handwritten'),
 ('Mountains of Christmas.ttf', 'Handwritten'),
 ('Londrina Outline.ttf', 'Display'),
 ('Boogaloo.ttf', 'Handwritten'),
 ('Tangerine.ttf', 'Handwritten'),
 ('Port Lligat Sans.ttf', 'Sans Serif'),
 ('Euphoria Script.ttf', 'Handwritten'),
 ('Romanesco.ttf', 'Handwritten'),
 ('Aguafina Script.ttf', 'Handwritten'),
 ('Herr Von Muellerhoff.ttf', 'Handwritten'),
 ('Finger Paint.ttf', 'Handwritten'),
 ('Sevillana.ttf', 'Handwritten'),
 ('Qwigley.ttf', 'Handwritten'),
 ('Sedgwick Ave.ttf', 'Handwritten'),
 ('Lobster Two.ttf', 'Handwritten'),
 ('Italianno.ttf', 'Handwritten'),
 ('Indie Flower.ttf', 'Handwritten'),
 ('Bilbo.ttf', 'Handwritten'),
 ('Rock Salt.ttf', 'Handwritten'),
 ('Short Stack.ttf', 'Display'),
 ('WindSong.ttf', 'Handwritten'),
 ('Sonsie One.ttf', 'Handwritten'),
 ('Caveat.ttf', 'Handwritten'),
 ('Prompt.ttf', 'Sans Serif'),
 ('Walter Turncoat.ttf', 'Display'),
 ('Satisfy.ttf', 'Handwritten'),
 ('Mouse Memoirs.ttf', 'Display'),
 ('Leckerli One.ttf', 'Handwritten'),
 ('Sedgwick Ave Display.ttf', 'Handwritten'),
 ('Yellowtail.ttf', 'Handwritten'),
 ('Ruthie.ttf', 'Handwritten'),
 ('Courgette.ttf', 'Handwritten'),
 ('Permanent Marker.ttf', 'Handwritten'),
 ('Caveat Brush.ttf', 'Display'),
 ('Londrina Sketch.ttf', 'Display'),
 ('Flavors.ttf', 'Handwritten'),
 ('Freehand.ttf', 'Handwritten'),
 ('Sofia.ttf', 'Handwritten'),
 ('Montez.ttf', 'Handwritten'),
 ('Almendra Display.ttf', 'Handwritten'),
 ('Alex Brush.ttf', 'Handwritten'),
 ('Sarina.ttf', 'Handwritten'),
 ('Chelsea Market.ttf', 'Display'),
 ('Quintessential.ttf', 'Handwritten'),
 ('Allura.ttf', 'Handwritten'),
 ('Chela One.ttf', 'Monospaced'),
 ('Nothing You Could Do.ttf', 'Handwritten'),
 ('Rancho.ttf', 'Display'),
 ('Londrina Shadow.ttf', 'Display'),
 ('Just Another Hand.ttf', 'Handwritten'),
 ('Almendra.ttf', 'Handwritten'),
 ('Allison.ttf', 'Handwritten'),
 ('Just Me Again Down Here.ttf', 'Handwritten'),
 ('Kaushan Script.ttf', 'Handwritten'),
 ('Kristi.ttf', 'Handwritten'),
 ('Bilbo Swash Caps.ttf', 'Handwritten'),
 ('Cookie.ttf', 'Handwritten'),
 ('Architects Daughter.ttf', 'Handwritten'),
 ('Arizonia.ttf', 'Handwritten'),
 ('Dynalight.ttf', 'Handwritten'),
 ('Song Myung.ttf', 'Serif'),
 ('RocknRoll One.ttf', 'Display'),
 ('Coustard.ttf', 'Serif'),
 ('Are You Serious.ttf', 'Handwritten'),
 ('Anonymous Pro.ttf', 'Monospaced'),
 ('Ramaraja.ttf', 'Serif'),
 ('Ramabhadra.ttf', 'Sans Serif'),
 ('Inconsolata.ttf', 'Monospaced'),
 ('PT Mono.ttf', 'Monospaced'),
 ('Lekton.ttf', 'Monospaced'),
 ('Source Code Pro.ttf', 'Monospaced'),
 ('Ubuntu Mono.ttf', 'Monospaced'),
 ('Fira Code.ttf', 'Monospaced'),
 ('Cousine.ttf', 'Monospaced'),
 ('Text Me One.ttf', 'Sans Serif'),
 ('Mouse Memoirs.ttf', 'Display'),
 ('Share Tech.ttf', 'Sans Serif'),
 ('Courier Prime.ttf', 'Monospaced'),
 ('Share Tech Mono.ttf', 'Monospaced'),
 ('Share.ttf', 'Sans Serif'),
 ('Oxygen Mono.ttf', 'Sans Serif'),
 ('IM Fell French Canon.ttf', 'Serif'),
 ('IM Fell DW Pica.ttf', 'Serif'),
 ('IM Fell Great Primer.ttf', 'Serif'),
 ('Vollkorn SC.ttf', 'Serif'),
 ('Metal.ttf', 'Handwritten'),
 ('IM Fell English SC.ttf', 'Serif'),
 ('Vidaloka.ttf', 'Serif'),
 ('Tienne.ttf', 'Serif'),
 ('Goblin One.ttf', 'Serif'),
 ('Mali.ttf', 'Display'),
 ('Risque.ttf', 'Handwritten'),
 ('Blinker.ttf', 'Sans Serif'),
 ('IM Fell DW Pica SC.ttf', 'Serif'),
 ('Henny Penny.ttf', 'Handwritten'),
 ('Metamorphous.ttf', 'Serif'),
 ('Metal Mania.ttf', 'Display'),
 ('Courier Prime.ttf', 'Serif'),
 ('Yeseva One.ttf', 'Serif'),
 ('IM Fell Double Pica SC.ttf', 'Serif'),
 ('IM Fell French Canon SC.ttf', 'Serif'),
 ('IM Fell Great Primer SC.ttf', 'Serif'),
 ('Kavoon.ttf', 'Handwritten'),
 ('Griffy.ttf', 'Handwritten'),
 ('IM Fell English.ttf', 'Serif'),
 ('Petrona.ttf', 'Serif'),
 ('IM Fell Double Pica.ttf', 'Serif'),
 ('Andada Pro.ttf', 'Serif'),
 ('Vollkorn.ttf', 'Serif'),
 ('Stardos Stencil.ttf', 'Serif'),
 ('Spinnaker.ttf', 'Sans Serif'),
 ('Mouse Memoirs.ttf', 'Display'),
 ('Archivo Narrow.ttf', 'Sans Serif'),
 ('Allerta.ttf', 'Sans Serif'),
 ('Six Caps.ttf', 'Sans Serif'),
 ('Days One.ttf', 'Sans Serif'),
 ('Bowlby One SC.ttf', 'Sans Serif'),
 ('Ubuntu Mono.ttf', 'Sans Serif'),
 ('Barrio.ttf', 'Display'),
 ('Francois One.ttf', 'Sans Serif'),
 ('Antonio.ttf', 'Sans Serif'),
 ('Bebas Neue.ttf', 'Sans Serif'),
 ('Oswald.ttf', 'Sans Serif'),
 ('Fjalla One.ttf', 'Sans Serif'),
 ('Candal.ttf', 'Sans Serif'),
 ('Archivo Black.ttf', 'Sans Serif'),
 ('Inconsolata.ttf', 'Monospaced'),
 ('Barriecito.ttf', 'Display'),
 ('Truculenta.ttf', 'Sans Serif'),
 ('Major Mono Display.ttf', 'Display'),
 ('Bowlby One.ttf', 'Sans Serif'),
 ('Source Code Pro.ttf', 'Monospaced'),
 ('Allan.ttf', 'Handwritten'),
 ('Jolly Lodger.ttf', 'Handwritten'),
 ('Allerta Stencil.ttf', 'Sans Serif'),
 ('Romanesco.ttf', 'Handwritten'),
 ('Caveat.ttf', 'Handwritten'),
 ('Recursive.ttf', 'Sans Serif'),
 ('Average.ttf', 'Serif'),
 ('Herr Von Muellerhoff.ttf', 'Handwritten'),
 ('Concert One.ttf', 'Sans Serif'),
 ('Source Code Pro.ttf', 'Monospaced'),
 ('Manuale.ttf', 'Serif'),
 ('Syne Tactile.ttf', 'Handwritten'),
 ('Handlee.ttf', 'Display'),
 ('Hind Siliguri.ttf', 'Sans Serif'),
 ('Faster One.ttf', 'Display'),
 ('Parisienne.ttf', 'Handwritten'),
 ('Aguafina Script.ttf', 'Handwritten'),
 ('Macondo.ttf', 'Display'),
 ('Bilbo.ttf', 'Handwritten'),
 ('Reenie Beanie.ttf', 'Handwritten'),
 ('Arbutus.ttf', 'Display'),
 ('Mr De Haviland.ttf', 'Handwritten'),
 ('WindSong.ttf', 'Handwritten'),
 ('IBM Plex Sans Thai.ttf', 'Sans Serif'),
 ('Chau Philomene One.ttf', 'Display'),
 ('Barlow.ttf', 'Sans Serif'),
 ('Sonsie One.ttf', 'Handwritten'),
 ('Delius Unicase.ttf', 'Display'),
 ('Noto Serif Display.ttf', 'Serif'),
 ('IBM Plex Mono.ttf', 'Sans Serif'),
 ('IBM Plex Sans Thai Looped.ttf', 'Sans Serif'),
 ('Calistoga.ttf', 'Serif'),
 ('Mandali.ttf', 'Sans Serif'),
 ('Karma.ttf', 'Serif'),
 ('Girassol.ttf', 'Serif'),
 ('Carrois Gothic.ttf', 'Sans Serif'),
 ('Indie Flower.ttf', 'Handwritten'),
 ('Passion One.ttf', 'Sans Serif'),
 ('Solway.ttf', 'Serif'),
 ('Sarpanch.ttf', 'Sans Serif'),
 ('Hind Madurai.ttf', 'Sans Serif'),
 ('Walter Turncoat.ttf', 'Display'),
 ('Arbutus Slab.ttf', 'Serif'),
 ('Prompt.ttf', 'Sans Serif'),
 ('Hind Guntur.ttf', 'Sans Serif'),
 ('Biryani.ttf', 'Sans Serif'),
 ('Acme.ttf', 'Display'),
 ('Expletus Sans.ttf', 'Display'),
 ('Averia Sans Libre.ttf', 'Display'),
 ('Delius.ttf', 'Display'),
 ('Monofett.ttf', 'Display'),
 ('Grenze Gotisch.ttf', 'Display'),
 ('Changa.ttf', 'Sans Serif'),
 ('Inria Sans.ttf', 'Sans Serif'),
 ('Cinzel.ttf', 'Sans Serif'),
 ('Carrois Gothic SC.ttf', 'Sans Serif'),
 ('Gochi Hand.ttf', 'Handwritten'),
 ('Assistant.ttf', 'Sans Serif'),
 ('Big Shoulders Stencil Text.ttf', 'Display'),
 ('Special Elite.ttf', 'Serif'),
 ('Big Shoulders Display.ttf', 'Sans Serif'),
 ('IBM Plex Serif.ttf', 'Serif'),
 ('Krona One.ttf', 'Sans Serif'),
 ('Asap Condensed.ttf', 'Sans Serif'),
 ('Mukta Malar.ttf', 'Sans Serif'),
 ('IBM Plex Sans Devanagari.ttf', 'Sans Serif'),
 ('Commissioner.ttf', 'Sans Serif'),
 ('PT Mono.ttf', 'Serif'),
 ('Tangerine.ttf', 'Handwritten'),
 ('Cagliostro.ttf', 'Display'),
 ('Bubbler One.ttf', 'Display'),
 ('Over the Rainbow.ttf', 'Handwritten'),
 ('Fontdiner Swanky.ttf', 'Display'),
 ('Shrikhand.ttf', 'Display'),
 ('Are You Serious.ttf', 'Handwritten'),
 ('Lobster Two.ttf', 'Handwritten'),
 ('Love Ya Like A Sister.ttf', 'Display'),
 ('Palanquin.ttf', 'Sans Serif'),
 ('Hind Vadodara.ttf', 'Sans Serif'),
 ('Sevillana.ttf', 'Handwritten'),
 ('Poiret One.ttf', 'Sans Serif'),
 ('Italianno.ttf', 'Handwritten'),
 ('Sedgwick Ave.ttf', 'Display'),
 ('Finger Paint.ttf', 'Display'),
 ('Averia Serif Libre.ttf', 'Sans Serif'),
 ('Literata.ttf', 'Serif'),
 ('Marvel.ttf', 'Sans Serif'),
 ('Alice.ttf', 'Serif'),
 ('Goldman.ttf', 'Sans Serif'),
 ('Euphoria Script.ttf', 'Handwritten'),
 ('Qwigley.ttf', 'Handwritten'),
 ('Alfa Slab One.ttf', 'Serif'),
 ('Vampiro One.ttf', 'Handwritten'),
 ('Arima Madurai.ttf', 'Sans Serif'),
 ('Telex.ttf', 'Sans Serif'),
 ('Lovers Quarrel.ttf', 'Handwritten'),
 ('Diplomata SC.ttf', 'Display'),
 ('Vibes.ttf', 'Display'),
 ('Dosis.ttf', 'Sans Serif'),
 ('VT323.ttf', 'Display'),
 ('Supermercado One.ttf', 'Display'),
 ('Lalezar.ttf', 'Sans Serif'),
 ('Uncial Antiqua.ttf', 'Serif'),
 ('Lobster.ttf', 'Handwritten'),
 ('Lateef.ttf', 'Serif'),
 ('Teko.ttf', 'Sans Serif'),
 ('Black Han Sans.ttf', 'Sans Serif'),
 ('Cookie.ttf', 'Handwritten'),
 ('Marcellus SC.ttf', 'Sans Serif'),
 ('Kavivanar.ttf', 'Display'),
 ('Shojumaru.ttf', 'Display'),
 ('Advent Pro.ttf', 'Sans Serif'),
 ('Rouge Script.ttf', 'Handwritten'),
 ('Nunito.ttf', 'Sans Serif'),
 ('Farro.ttf', 'Sans Serif'),
 ('Dancing Script.ttf', 'Handwritten'),
 ('Public Sans.ttf', 'Sans Serif'),
 ('Rye.ttf', 'Display'),
 ('Mukta Vaani.ttf', 'Sans Serif'),
 ('Sail.ttf', 'Handwritten'),
 ('Londrina Outline.ttf', 'Sans Serif'),
 ('IBM Plex Sans.ttf', 'Sans Serif'),
 ('Alef.ttf', 'Sans Serif'),
 ('Zilla Slab.ttf', 'Serif'),
 ('Pacifico.ttf', 'Handwritten'),
 ('Chathura.ttf', 'Sans Serif'),
 ('IBM Plex Sans Arabic.ttf', 'Sans Serif'),
 ('Belleza.ttf', 'Sans Serif'),
 ('Squada One.ttf', 'Sans Serif'),
 ('Red Rose.ttf', 'Display'),
 ('ABeeZee.ttf', 'Sans Serif'),
 ('Anonymous Pro.ttf', 'Serif'),
 ('Passions Conflict.ttf', 'Handwritten'),
 ('Englebert.ttf', 'Display'),
 ('Abel.ttf', 'Sans Serif'),
 ('Cinzel Decorative.ttf', 'Serif'),
 ('Condiment.ttf', 'Handwritten'),
 ('Amita.ttf', 'Display'),
 ('Sen.ttf', 'Sans Serif'),
 ('Michroma.ttf', 'Sans Serif'),
 ('Mr Dafoe.ttf', 'Handwritten'),
 ('Fredericka the Great.ttf', 'Serif'),
 ('Ramaraja.ttf', 'Serif'),
 ('Fauna One.ttf', 'Serif'),
 ('Inter.ttf', 'Sans Serif'),
 ('Ramabhadra.ttf', 'Sans Serif'),
 ('Days One.ttf', 'Sans Serif'),
 ('Miniver.ttf', 'Handwritten'),
 ('Schoolbell.ttf', 'Display'),
 ('Smokum.ttf', 'Display'),
 ('Nosifer.ttf', 'Display'),
 ('Electrolize.ttf', 'Sans Serif'),
 ('Candal.ttf', 'Sans Serif'),
 ('Peralta.ttf', 'Serif'),
 ('Mali.ttf', 'Display'),
 ('Kotta One.ttf', 'Serif'),
 ('Texturina.ttf', 'Serif'),
 ('Kaushan Script.ttf', 'Display'),
 ('Barlow Semi Condensed.ttf', 'Sans Serif'),
 ('Grandstander.ttf', 'Sans Serif'),
 ('Ranchers.ttf', 'Display'),
 ('Atomic Age.ttf', 'Serif'),
 ('Marcellus.ttf', 'Sans Serif'),
 ('Prata.ttf', 'Serif'),
 ('Delius Swash Caps.ttf', 'Display'),
 ('Happy Monkey.ttf', 'Sans Serif'),
 ('Codystar.ttf', 'Display'),
 ('Fasthand.ttf', 'Handwritten'),
 ('Hind.ttf', 'Sans Serif'),
 ('League Script.ttf', 'Handwritten'),
 ('Bebas Neue.ttf', 'Sans Serif'),
 ('Bilbo Swash Caps.ttf', 'Handwritten'),
 ('Philosopher.ttf', 'Sans Serif'),
 ('Diplomata.ttf', 'Serif'),
 ('Gorditas.ttf', 'Serif'),
 ('Just Me Again Down Here.ttf', 'Handwritten'),
 ('Rozha One.ttf', 'Serif'),
 ('Share.ttf', 'Sans Serif'),
 ('Bona Nova.ttf', 'Serif'),
 ('Dynalight.ttf', 'Handwritten'),
 ('Karantina.ttf', 'Sans Serif'),
 ('Arizonia.ttf', 'Handwritten'),
 ('Londrina Solid.ttf', 'Sans Serif'),
 ('Manrope.ttf', 'Sans Serif'),
 ('Oxygen Mono.ttf', 'Sans Serif'),
 ('Averia Libre.ttf', 'Display'),
 ('Great Vibes.ttf', 'Handwritten'),
 ('The Girl Next Door.ttf', 'Handwritten'),
 ('Kalam.ttf', 'Display'),
 ('Homenaje.ttf', 'Sans Serif'),
 ('Black Ops One.ttf', 'Display'),
 ('Spectral.ttf', 'Serif'),
 ('IBM Plex Sans Hebrew.ttf', 'Sans Serif'),
 ('Zilla Slab Highlight.ttf', 'Serif'),
 ('Martel Sans.ttf', 'Sans Serif'),
 ('Merienda.ttf', 'Display'),
 ('Oxanium.ttf', 'Sans Serif'),
 ('Paprika.ttf', 'Display'),
 ('Catamaran.ttf', 'Sans Serif'),
 ('Julius Sans One.ttf', 'Sans Serif'),
 ('Gafata.ttf', 'Sans Serif'),
 ('Odibee Sans.ttf', 'Sans Serif'),
 ('Red Hat Text.ttf', 'Sans Serif'),
 ('Graduate.ttf', 'Serif'),
 ('Chela One.ttf', 'Display'),
 ('Rowdies.ttf', 'Display'),
 ('Oranienbaum.ttf', 'Serif'),
 ('Libre Caslon Display.ttf', 'Serif'),
 ('IBM Plex Sans Condensed.ttf', 'Sans Serif'),
 ('Noto Sans Mono.ttf', 'Sans Serif'),
 ('Creepster.ttf', 'Display'),
 ('Spartan.ttf', 'Sans Serif'),
 ('Syne.ttf', 'Sans Serif'),
 ('Fredoka One.ttf', 'Sans Serif'),
 ('M PLUS Code Latin.ttf', 'Sans Serif'),
 ('Merienda One.ttf', 'Handwritten'),
 ('Chango.ttf', 'Display'),
 ('Bevan.ttf', 'Display'),
 ('Style Script.ttf', 'Handwritten'),
 ('Germania One.ttf', 'Display'),
 ('Londrina Shadow.ttf', 'Display'),
 ('Rancho.ttf', 'Display'),
 ('Kelly Slab.ttf', 'Serif'),
 ('Nothing You Could Do.ttf', 'Handwritten'),
 ('Jomhuria.ttf', 'Sans Serif'),
 ('Big Shoulders Text.ttf', 'Sans Serif'),
 ('Allura.ttf', 'Monospaced'),
 ('Barriecito.ttf', 'Display'),
 ('Big Shoulders Inline Display.ttf', 'Display'),
 ('Red Hat Display.ttf', 'Sans Serif'),
 ('Beth Ellen.ttf', 'Handwritten'),
 ('Sarina.ttf', 'Handwritten'),
 ('Truculenta.ttf', 'Sans Serif'),
 ('Khula.ttf', 'Sans Serif'),
 ('Didact Gothic.ttf', 'Sans Serif'),
 ('Life Savers.ttf', 'Serif'),
 ('Chelsea Market.ttf', 'Display'),
 ('Just Another Hand.ttf', 'Display'),
 ('Quintessential.ttf', 'Serif'),
 ('Road Rage.ttf', 'Display'),
 ('Mukta.ttf', 'Sans Serif'),
 ('Palanquin Dark.ttf', 'Sans Serif'),
 ('Darker Grotesque.ttf', 'Sans Serif'),
 ('Ruda.ttf', 'Sans Serif'),
 ('Bigelow Rules.ttf', 'Display'),
 ('Average Sans.ttf', 'Sans Serif'),
 ('Noto Serif.ttf', 'Serif'),
 ('Niconne.ttf', 'Handwritten'),
 ('Kirang Haerang.ttf', 'Display'),
 ('Estonia.ttf', 'Handwritten'),
 ('Passero One.ttf', 'Display'),
 ('Courgette.ttf', 'Display'),
 ('Rochester.ttf', 'Handwritten'),
 ('Yantramanav.ttf', 'Sans Serif'),
 ('Syncopate.ttf', 'Display'),
 ('Big Shoulders Inline Text.ttf', 'Display'),
 ('Barlow Condensed.ttf', 'Sans Serif'),
 ('Syne Mono.ttf', 'Display'),
 ('Noto Sans.ttf', 'Sans Serif'),
 ('Caveat Brush.ttf', 'Display'),
 ('Averia Gruesa Libre.ttf', 'Sans Serif'),
 ('Mohave.ttf', 'Sans Serif'),
 ('Sirin Stencil.ttf', 'Display'),
 ('Tillana.ttf', 'Display'),
 ('Homemade Apple.ttf', 'Handwritten'),
 ('Ledger.ttf', 'Serif'),
 ('Mukta Mahee.ttf', 'Sans Serif'),
 ('Freehand.ttf', 'Monospaced'),
 ('Inria Serif.ttf', 'Serif'),
 ('Marck Script.ttf', 'Handwritten'),
 ('Asset.ttf', 'Serif'),
 ('Vast Shadow.ttf', 'Serif'),
 ('Share Tech Mono.ttf', 'Sans Serif'),
 ('Spirax.ttf', 'Display'),
 ('Ranga.ttf', 'Display'),
 ('Vibur.ttf', 'Handwritten'),
 ('Ruthie.ttf', 'Handwritten'),
 ('El Messiri.ttf', 'Sans Serif'),
 ('Archivo.ttf', 'Sans Serif'),
 ('Libre Caslon Text.ttf', 'Serif'),
 ('Changa One.ttf', 'Sans Serif'),
 ('Londrina Sketch.ttf', 'Sans Serif'),
 ('Gotu.ttf', 'Sans Serif'),
 ('Salsa.ttf', 'Display'),
 ('Farsan.ttf', 'Display'),
 ('Major Mono Display.ttf', 'Display'),
 ('Spectral SC.ttf', 'Serif'),
 ('Sofadi One.ttf', 'Display'),
 ('Sofia.ttf', 'Handwritten'),
 ('Barrio.ttf', 'Display'),
 ('Share Tech.ttf', 'Sans Serif'),
 ('Abhaya Libre.ttf', 'Serif'),
 ('Baumans.ttf', 'Display'),
 ('Heebo.ttf', 'Sans Serif'),
 ('Alex Brush.ttf', 'Handwritten'),
 ('Ceviche One.ttf', 'Display'),
 ('Pragati Narrow.ttf', 'Sans Serif'),
 ('Luckiest Guy.ttf', 'Display'),
 ('Benne.ttf', 'Serif'),
 ('Nanum Pen Script.ttf', 'Display'),
 ('Nanum Gothic.ttf', 'Sans Serif'),
 ('Gowun Batang.ttf', 'Serif'),
 ('Gaegu.ttf', 'Display'),
 ('Noto Serif SC.ttf', 'Serif'),
 ('Noto Serif KR.ttf', 'Serif'),
 ('Satisfy.ttf', 'Handwritten'),
 ('Noto Serif TC.ttf', 'Serif'),
 ('Sawarabi Gothic.ttf', 'Sans Serif'),
 ('Explora.ttf', 'Handwritten'),
 ('Red Hat Mono.ttf', 'Sans Serif'),
 ('Macondo Swash Caps.ttf', 'Display'),
 ('Big Shoulders Stencil Display.ttf', 'Display'),
 ('Modak.ttf', 'Display'),
 ('Italiana.ttf', 'Sans Serif'),
 ('Loved by the King.ttf', 'Handwritten'),
 ('Faustina.ttf', 'Serif'),
 ('Erica One.ttf', 'Display'),
 ('Sedgwick Ave Display.ttf', 'Handwritten'),
 ('Francois One.ttf', 'Sans Serif'),
 ('Croissant One.ttf', 'Serif'),
 ('Glory.ttf', 'Display'),
 ('M PLUS 1 Code.ttf', 'Sans Serif'),
 ('Yuji Boku.ttf', 'Handwritten'),
 ('Grand Hotel.ttf', 'Handwritten'),
 ('Gloria Hallelujah.ttf', 'Display'),
 ('Besley.ttf', 'Serif'),
 ('Grenze.ttf', 'Serif'),
 ('Baskervville.ttf', 'Serif'),
 ('Bellefair.ttf', 'Serif'),
 ('Amiko.ttf', 'Sans Serif'),
 ('Fraunces.ttf', 'Serif'),
 ('Nanum Brush Script.ttf', 'Display'),
 ('M PLUS 2.ttf', 'Sans Serif'),
 ('Yuji Syuku.ttf', 'Serif'),
 ('Gowun Dodum.ttf', 'Sans Serif'),
 ('Noto Sans TC.ttf', 'Sans Serif'),
 ('Gothic A1.ttf', 'Sans Serif'),
 ('Stylish.ttf', 'Serif'),
 ('Nanum Gothic Coding.ttf', 'Monospaced'),
 ('Song Myung.ttf', 'Serif'),
 ('Noto Serif JP.ttf', 'Serif'),
 ('Black And White Picture.ttf', 'Display'),
 ('Noto Sans SC.ttf', 'Sans Serif'),
 ('M PLUS Rounded 1c.ttf', 'Sans Serif'),
 ('Sawarabi Mincho.ttf', 'Serif'),
 ('Yuji Mai.ttf', 'Serif'),
 ('Noto Sans JP.ttf', 'Sans Serif'),
 ('M PLUS 1p.ttf', 'Sans Serif'),
 ('M PLUS 1.ttf', 'Sans Serif'),
 ('Nanum Myeongjo.ttf', 'Serif'),
 ('Noto Sans KR.ttf', 'Sans Serif'),
 ('IBM Plex Sans KR.ttf', 'Sans Serif'),
 ('Noto Sans HK.ttf', 'Sans Serif')]

# %%
tmp = []
for i in data[:1000]:
  for j in data2:
    if i[0] == j[0] and i[1] != j[1]:
      print(i, j)
# Out:
# ('Vibes.ttf', 'Handwritten') ('Vibes.ttf', 'Display')
# ('Englebert.ttf', 'Handwritten') ('Englebert.ttf', 'Display')
# ('Petrona.ttf', 'Handwritten') ('Petrona.ttf', 'Serif')
# ('Londrina Outline.ttf', 'Display') ('Londrina Outline.ttf', 'Sans Serif')
# ('Finger Paint.ttf', 'Handwritten') ('Finger Paint.ttf', 'Display')
# ('Sedgwick Ave.ttf', 'Handwritten') ('Sedgwick Ave.ttf', 'Display')
# ('Courgette.ttf', 'Handwritten') ('Courgette.ttf', 'Display')
# ('Londrina Sketch.ttf', 'Display') ('Londrina Sketch.ttf', 'Sans Serif')
# ('Freehand.ttf', 'Handwritten') ('Freehand.ttf', 'Monospaced')
# ('Quintessential.ttf', 'Handwritten') ('Quintessential.ttf', 'Serif')
# ('Allura.ttf', 'Handwritten') ('Allura.ttf', 'Monospaced')
# ('Chela One.ttf', 'Monospaced') ('Chela One.ttf', 'Display')
# ('Just Another Hand.ttf', 'Handwritten') ('Just Another Hand.ttf', 'Display')
# ('Kaushan Script.ttf', 'Handwritten') ('Kaushan Script.ttf', 'Display')
# ...

# %%
data2 = [('Mouse Memoirs.ttf', 'Display') ,
('Courier Prime.ttf', 'Serif') ,
('Petrona.ttf', 'Serif') ,
('Mouse Memoirs.ttf', 'Display') ,
('Ubuntu Mono.ttf', 'Sans Serif') ,
('Inconsolata.ttf', 'Monospaced') ,
('Source Code Pro.ttf', 'Monospaced') ,
('Romanesco.ttf', 'Handwritten') ,
('Caveat.ttf', 'Handwritten') ,
('Herr Von Muellerhoff.ttf', 'Handwritten') ,
('Source Code Pro.ttf', 'Monospaced') ,
('Aguafina Script.ttf', 'Handwritten') ,
('Bilbo.ttf', 'Handwritten') ,
('WindSong.ttf', 'Handwritten') ,
('Sonsie One.ttf', 'Handwritten') ,
('Indie Flower.ttf', 'Handwritten') ,
('Walter Turncoat.ttf', 'Display') ,
('Prompt.ttf', 'Sans Serif') ,
('PT Mono.ttf', 'Serif') ,
('Tangerine.ttf', 'Handwritten') ,
('Are You Serious.ttf', 'Handwritten') ,
('Lobster Two.ttf', 'Handwritten') ,
('Sevillana.ttf', 'Handwritten') ,
('Italianno.ttf', 'Handwritten') ,
('Sedgwick Ave.ttf', 'Display') ,
('Finger Paint.ttf', 'Display') ,
('Euphoria Script.ttf', 'Handwritten') ,
('Qwigley.ttf', 'Handwritten') ,
('Vibes.ttf', 'Display') ,
('Lobster.ttf', 'Handwritten') ,
('Cookie.ttf', 'Handwritten') ,
('Dancing Script.ttf', 'Handwritten') ,
('Sail.ttf', 'Handwritten') ,
('Londrina Outline.ttf', 'Sans Serif') ,
('Pacifico.ttf', 'Handwritten') ,
('Anonymous Pro.ttf', 'Serif') ,
('Englebert.ttf', 'Display') ,
('Ramaraja.ttf', 'Serif') ,
('Ramabhadra.ttf', 'Sans Serif') ,
('Days One.ttf', 'Sans Serif') ,
('Candal.ttf', 'Sans Serif') ,
('Mali.ttf', 'Display') ,
('Kaushan Script.ttf', 'Display') ,
('Bebas Neue.ttf', 'Sans Serif') ,
('Bilbo Swash Caps.ttf', 'Handwritten') ,
('Just Me Again Down Here.ttf', 'Handwritten') ,
('Share.ttf', 'Sans Serif') ,
('Dynalight.ttf', 'Handwritten') ,
('Arizonia.ttf', 'Handwritten') ,
('Londrina Solid.ttf', 'Sans Serif') ,
('Oxygen Mono.ttf', 'Sans Serif') ,
('Great Vibes.ttf', 'Handwritten') ,
('Chela One.ttf', 'Display') ,
('Londrina Shadow.ttf', 'Display') ,
('Rancho.ttf', 'Display') ,
('Nothing You Could Do.ttf', 'Handwritten') ,
('Allura.ttf', 'Monospaced') ,
('Barriecito.ttf', 'Display') ,
('Sarina.ttf', 'Handwritten') ,
('Truculenta.ttf', 'Sans Serif') ,
('Chelsea Market.ttf', 'Display') ,
('Just Another Hand.ttf', 'Display') ,
('Quintessential.ttf', 'Serif') ,
('Courgette.ttf', 'Display') ,
('Caveat Brush.ttf', 'Display') ,
('Freehand.ttf', 'Monospaced') ,
('Share Tech Mono.ttf', 'Sans Serif') ,
('Ruthie.ttf', 'Handwritten') ,
('Londrina Sketch.ttf', 'Sans Serif') ,
('Major Mono Display.ttf', 'Display') ,
('Sofia.ttf', 'Handwritten') ,
('Barrio.ttf', 'Display') ,
('Share Tech.ttf', 'Sans Serif') ,
('Alex Brush.ttf', 'Handwritten') ,
('Satisfy.ttf', 'Handwritten') ,
('Sedgwick Ave Display.ttf', 'Handwritten') ,
('Francois One.ttf', 'Sans Serif') ,
('Song Myung.ttf', 'Serif')]

# %%
'Benne.ttf' in os.listdir(pathToSave + 'Serif')
# Out:
# True

# %%
pathToAll = '/content/drive/MyDrive/colabData/fontData/allFonts/'
pathToSave = '/content/drive/MyDrive/colabData/fontData/data/txtClassification/'
cnt = 0
for i in data[:1000]:
  cnt += 1
  if i[0] not in os.listdir(pathToSave + 'Display') \
      and i[0] not in os.listdir(pathToSave + 'Serif') \
      and i[0] not in os.listdir(pathToSave + 'Sans Serif') \
      and i[0] not in os.listdir(pathToSave + 'Monospaced') \
      and i[0] not in os.listdir(pathToSave + 'Handwritten'):
    print(i)
    try:
      sysString = 'copy ' + pathToAll + i[0] + ' ' + pathToSave + i[1] + '/' + i[0]
      # print(sysString)
      os.replace(pathToAll + i[0], pathToSave + i[1] + '/' + i[0])
    except FileNotFoundError:
      pass
print(cnt)
# Out:
# 499

# %% [markdown]
# Create Classification: Handwritten - 93 pieces / Other - 423 pieces

# %%
print(data)
# Out:
# {'date': '22.03.2022', 'fonts': [{'family': 'ABeeZee', 'variants': ['regular', 'italic'], 'subsets': ['latin'], 'tags': ['Display', 'Informal', 'Oblique', 'Paragraph', 'Sans, Geometric'], 'version': 'v14', 'fonts': {'400': {'thickness': 5, 'slant': 1, 'width': 7, 'lineHeight': 1.182}, '400i': {'thickness': 5, 'slant': 4, 'width': 7, 'lineHeight': 1.182}}, 'axes': [], 'unsupportedAxes': [], 'designers': ['Anja Meiners'], 'lastModified': '2022-01-26', 'dateAdded': '2012-09-30', 'popularity': 131, 'trending': 654, 'defaultSort': 129, 'files': {'regular': 'http://fonts.gstatic.com/s/abeezee/v14/esDR31xSG-6AGleN6tKukbcHCpE.ttf', 'italic': 'http://fonts.gstatic.com/s/abeezee/v14/esDT31xSG-6AGleN2tCklZUCGpG-GQ.ttf'}, 'category': 'sans-serif', 'classification': 'Sans Serif', 'kind': 'webfonts#webfont'}, {'family': 'Abel', 'variants': ['regular'], 'subsets': ['latin'], 'tags': ['Display', 'Paragraph'], 'version': 'v12', 'fonts': {'400': {'thickness': 4, 'slant': 1, 'width': 2, 'lineHeight': 1
# ...

# %%
cnt
# Out:
# 166

# %%
uniquer = ['']
cnt = 0
cnt1 = 0
for idx, el in enumerate(data['fonts'][:1000]):
  for target in el['files']:
    if target in uniquer:
      continue
    uniquer.append(target)  
    # print(target)
uniquer[0] = 'Количество тегов: '+str(len(uniquer))
print(uniquer)

#   if 'regular' in idx['files']:
#     url = idx['files']['regular']
#     name = idx['family']+'.ttf'

#     if idx['category'] == 'sans-serif' and 'latin' not in idx['subsets']:
#       # print(idx['family']+'.ttf')
#       # print(idx['files']['regular'])
#       # urllib.request.urlretrieve(url, sansPath + '/' + name)
#       print(idx['family']+'.ttf')
#       cnt += 1
#     elif idx['category'] == 'serif' and 'latin' not in idx['subsets']:
#       # print(idx['family']+'.ttf', 'serif')
#       # print(idx['files']['regular'])
#       # urllib.request.urlretrieve(url, serifPath + '/' + name)
#       print(idx['family']+'.ttf', 'serif')
#       cnt1 += 1 
#     # if idx['category'] in uniquer:
#     #   continue
#     # uniquer.append(str(idx['category']))
#   # print(uniquer)
# print(cnt)
# print(cnt1)
# Out:
# ['Количество тегов: 19', 'regular', 'italic', '500', '600', '700', '800', '100', '200', '300', '900', '500italic', '600italic', '700italic', '800italic', '900italic', '100italic', '300italic', '200italic']

# %%
myStr = ''
for i in uniquer:
  myStr += '!'+str(i)
print(myStr)
# Out:
# !Количество тегов: 136!Display!Informal!Oblique!Paragraph!Sans, Geometric!Headings!Serif, Modern!Heavy!Contemporary!Sans, Square!Calligraphic!Narrow!Quill!Condensed!Sans, Neo-humanist!Elegant!Small Caps!Black!Bold!Humanist!Light!Sans, Humanist!Ultra Light!Feminine!Formal!Invitations!Serif, Slab!Serif, Transitional!Corporate!Headline!Sans Serif!Sans, Grotesque!Fantasy!Historical!Medieval!Wedding!Handwritten!Serif!True Italics!Monospaced!Programming!Typewriter!Western!Architectural!Cute!High-tech!Brushed!Decorative!Geometric!Soft!1940s!1950s!1960s!Casual!Cut Paper!Handmade!Poster!Square!Rounded!All Caps!Art Deco!Marker!Uneven!High Contrast!Serif, Latin!Swashed!Rough!Novelty!Handrawn!Script!Wide!Military!Chiseled!Industrial!Childish!Comic!Inline!Monolinear!Outline!Shadowed!Cursive!Brush!Brushed Script!Scary!Futuristic!Grunge!Curly!1500s!Retro!Classical!Dots!Numbers!Clean!Octagon!Dotted!Led!Pixel!Serif, Flare!Angled!Stencil!Masculine!Techno!Paint!Borders And Frames!Ornaments!Icons!Kids!C
# ...

# %%
data['fonts'][166]
# Out:
# {'Antiqua_Sub_Classification': 'None',
#  'Contrast': 'None',
#  'Grotesque_Sub_Classification': 'None',
#  'Slant': [],
#  'Typography': [],
#  'Weight': ['Black', 'Bold', 'Heavy'],
#  'Width': [],
#  'axes': [],
#  'classification': 'Display',
#  'dateAdded': '2011-02-09',
#  'defaultSort': 529,
#  'designers': ['Vernon Adams'],
#  'family': 'Coda Caption',
#  'files': {'800': 'http://fonts.gstatic.com/s/codacaption/v14/ieVm2YRII2GMY7SyXSoDRiQGqcx6x_-fACIgaw.ttf'},
#  'fonts': {'800': {'lineHeight': 1.57861328125,
#    'slant': 1,
#    'thickness': 8,
#    'width': 8}},
#  'lastModified': '2022-01-11',
#  'popularity': 526,
#  'subsets': ['latin', 'latin-ext'],
#  'tags': ['Black', 'Bold', 'Heavy', 'Industrial'],
#  'trending': 81,
#  'unsupportedAxes': [],
#  'variants': ['800'],
#  'version': 'v14'}

# %%
uniquer = ['']
cnt = 0
cnt1 = 0
for el, idx in enumerate(data['fonts'][:1000]):
  if 'regular' in idx['files']:
    url = idx['files']['regular']
    name = idx['family']+'.ttf'

    if idx['category'] == 'sans-serif' and 'latin' not in idx['subsets']:
      # print(idx['family']+'.ttf')
      # print(idx['files']['regular'])
      # urllib.request.urlretrieve(url, sansPath + '/' + name)
      print(idx['family']+'.ttf')
      cnt += 1
    elif idx['category'] == 'serif' and 'latin' not in idx['subsets']:
      # print(idx['family']+'.ttf', 'serif')
      # print(idx['files']['regular'])
      # urllib.request.urlretrieve(url, serifPath + '/' + name)
      print(idx['family']+'.ttf', 'serif')
      cnt1 += 1 
    # if idx['category'] in uniquer:
    #   continue
    # uniquer.append(str(idx['category']))
  # print(uniquer)
print(cnt)
print(cnt1)

# %%
uniquer = ['']
cnt = 0
cnt1 = 0
for el, idx in enumerate(data['fonts'][:1000]):
  if 'regular' in idx['files'] and 'latin' in idx['subsets'] and 'Oblique' not in idx['tags'] \
  and 'Cursive' not in idx['tags'] and 'True Italics' not in idx['tags'] and 'True Italics' not in idx['tags'] \
  and 'Calligraphic' not in idx['tags'] and 'Serif' not in idx['tags'] and idx['category'] != 'serif' and idx['category'] != 'Serif' \
  and 'Handwritten' not in idx['tags'] and 'Handmade' not in idx['tags'] and 'Comic' not in idx['tags'] and 'Scary' not in idx['tags'] \
  and 'Paragraph' not in idx['tags'] and idx['category'] != 'handwriting':
    url = idx['files']['regular']
    name = idx['family']+'.ttf'
    print(idx['tags'])
    urllib.request.urlretrieve(url,  '/content/drive/MyDrive/colabData/fontData/data/slab/notOblique/' + name)
    cnt+=1

print(cnt)
print(cnt1)

# %% [markdown]
# ## Create database serif/sansSerif

# %%
import os

num_skipped = 0
cnt = 0
for folder_name in ("None High Contrast", "High Contrast"):
    folder_path = os.path.join("/content/drive/MyDrive/colabData/fontData/data/manualContrast/", folder_name)
    for fname in os.listdir(folder_path):
        cnt += 1
        fpath = os.path.join(folder_path, fname)
        # print(fpath)
        # print('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.png')
        # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'
        for i in range(20):
          generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/manualContrast/'+folder_name+'/'+fname[:-4]+str(i)+'.png')
          # print("!")
    #     if cnt == 5:
    #       break
    # break
    print('Подготовлено шрифтов:', cnt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a81655240674> in <module>()
#      12         # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'
#      13         for i in range(20):
# ---> 14           generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/manualContrast/'+folder_name+'/'+fname[:-4]+str(i)+'.png')
#      15           # print("!")
#      16     #     if cnt == 5:
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2129                 fp = builtins.open(filename, "r+b")
#    2130             else:
# -> 2131                 fp = builtins.open(filename, "w+b")
#    2132
#    2133         try:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create database width: narrow/condenced/wide

# %%
import os

cnt = 0
for el, idx in enumerate(data['fonts'][:1000]):
  if 'Wide' in idx['tags']:
    
    try:
      url = idx['files']['regular']
      name = idx['family']+'.ttf'
    except KeyError:
      keys = list(idx['files'].keys())
      url = idx['files'][keys[0]]
      name = idx['family']+'.ttf'
      print(url)

    urllib.request.urlretrieve(url,  '/content/drive/MyDrive/colabData/fontData/data/width/Wide/' + name)
    cnt+=1

print(cnt)
# Out:
# 3

# %% [markdown]
# ## Create database weight: 100/200/300/regular/400/500/600/700/800/900

# %%
import os
compare1 = ['ultralight', 'thin', 'light', 'regular', 'medium', 'semibold', 'bold', 'heavy', 'black']
compare2 = ['100',        '200',  '300',   'regular', '500',    '600',      '700',  '800',   '900' ]
compare2 = ['regular', 'italic', '500', '600', '700', '800', '100', '200', '300', '900', '500italic', '600italic', '700italic', '800italic', '900italic', '100italic', '300italic', '200italic']

cnt = 0
for idx, el in enumerate(data['fonts'][:1000]):
  for ind, categ in enumerate(compare1):

    try:
      url = el['files'][compare2[ind]]
      name = el['family']+'#'+compare2[ind]+'.ttf'
      urllib.request.urlretrieve(url,  '/content/drive/MyDrive/colabData/fontData/allFonts/' + name)
    except KeyError:
      # keys = list(idx['files'].keys())
      # url = idx['files'][keys[0]]
      # name = idx['family']+'.ttf'
      # print('Fail')
      pass

    # urllib.request.urlretrieve(url,  '/content/drive/MyDrive/colabData/fontData/data/width/Wide/' + name)
    cnt+=1

print(cnt)
# Out:
# 8262

# %%
len(data['fonts'])
# Out:
# 918

# %%
len(os.listdir('/content/drive/MyDrive/colabData/fontData/allFonts'))
# Out:
# 2697

# %% [markdown]
# ## Create database slab: oblique/trueItalic/cursive

# %%
import os

num_skipped = 0
cnt = 0
for folder_name in ("oblique", "notOblique"):
    folder_path = os.path.join("/content/drive/MyDrive/colabData/fontData/data/slab/", folder_name)
    for fname in os.listdir(folder_path)[:50]:
        cnt += 1
        fpath = os.path.join(folder_path, fname)
        # print(fpath)
        # print('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.png')
        # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'
        for i in range(1):
          generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/slab/img/'+folder_name+'/'+fname[:-4]+str(i)+'.png')
          # print("!")
    #     if cnt == 5:
    #       break
    # break
    print('Подготовлено шрифтов:', cnt)
        # generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+fname[:-4]+'.png')
#         try:
#             fobj = open(fpath, "rb")
#             is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
#         finally:
#             fobj.close()

#         if not is_jfif:
#             num_skipped += 1
#             # Delete corrupted image
#             os.remove(fpath)

# print("Deleted %d images" % num_skipped)
# Out:
# Подготовлено шрифтов: 50
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-31361fb45995> in <module>()
#       5 for folder_name in ("notOblique", "te"):
#       6     folder_path = os.path.join("/content/drive/MyDrive/colabData/fontData/data/slab/", folder_name)
# ----> 7     for fname in os.listdir(folder_path)[:50]:
#       8         cnt += 1
#       9         fpath = os.path.join(folder_path, fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/colabData/fontData/data/slab/te'

# %% [markdown]
# ## Create database serif/sansSerif

# %%
import os

num_skipped = 0
cnt = 0
for folder_name in ("sans serif", "serif"):
    folder_path = os.path.join("/content/drive/MyDrive/colabData/fontData/data/", folder_name)
    for fname in os.listdir(folder_path):
        cnt += 1
        fpath = os.path.join(folder_path, fname)
        # print(fpath)
        # print('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.png')
        # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'
        for i in range(20):
          generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data2/img/'+folder_name+'/'+fname[:-4]+str(i)+'.png')
          # print("!")
    #     if cnt == 5:
    #       break
    # break
    print('Подготовлено шрифтов:', cnt)
        # generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+fname[:-4]+'.png')
#         try:
#             fobj = open(fpath, "rb")
#             is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
#         finally:
#             fobj.close()

#         if not is_jfif:
#             num_skipped += 1
#             # Delete corrupted image
#             os.remove(fpath)

# print("Deleted %d images" % num_skipped)
# Out:
# Подготовлено шрифтов: 350
# Подготовлено шрифтов: 375
# Подготовлено шрифтов: 404
# Подготовлено шрифтов: 423
# Подготовлено шрифтов: 499

# %% [markdown]
# ## Create database Classifcation

# %%
ratio = [350, 25, 29, 19,76]

# %%
import os

num_skipped = 0
cnt = 0
for idx, folder_name in enumerate(('Display', 'Sans Serif', 'Serif', 'Monospaced', 'Handwritten')):
    folder_path = os.path.join("/content/drive/MyDrive/colabData/fontData/data/classification/", folder_name)
    cnt = 0
    for fname in os.listdir(folder_path):
        cnt += 1
        fpath = os.path.join(folder_path, fname)
        # print(fpath)
        # print('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.png')
        # fullName = '/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+'/'+fname[:-4]+'.jpg'
        samples = 20
        quantity = int(max(ratio)/ratio[idx])
        for i in range(samples*quantity):
          generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/classification/imgNormal/'+folder_name+'1/'+fname[:-4]+str(i)+'.jpg')
          # print("!")
    #     if cnt == 5:
    #       break
    # break
    print('Подготовлено шрифтов типа {}: {} в количестве {}x{} экземпляров на один шрифт'.format(folder_name, cnt, samples, quantity))
        # generateRandomSample(fpath).save('/content/drive/MyDrive/colabData/fontData/data/img/'+folder_name+fname[:-4]+'.png')
#         try:
#             fobj = open(fpath, "rb")
#             is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
#         finally:
#             fobj.close()

#         if not is_jfif:
#             num_skipped += 1
#             # Delete corrupted image
#             os.remove(fpath)

# print("Deleted %d images" % num_skipped)
# Out:
# Подготовлено шрифтов типа Display: 350 в количестве 20x1 экземпляров на один шрифт
# Подготовлено шрифтов типа Sans Serif: 25 в количестве 20x14 экземпляров на один шрифт
# Подготовлено шрифтов типа Serif: 29 в количестве 20x12 экземпляров на один шрифт
# Подготовлено шрифтов типа Monospaced: 19 в количестве 20x18 экземпляров на один шрифт
# Подготовлено шрифтов типа Handwritten: 76 в количестве 20x4 экземпляров на один шрифт
